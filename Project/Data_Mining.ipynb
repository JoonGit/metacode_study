# %%
import pandas as pd

# 데이터 불러오기
food_df = pd.read_excel('./data/20251229_음식DB 19495건.xlsx')
shop_df = pd.read_csv('./data/모범음식점정보_서울강서구.csv', encoding='cp949')
perchase_df = pd.read_csv('./data/한국산림복지진흥원_산림복지전문업지원시스템 결제정보_20210630.csv', encoding='utf-8')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1516\1962329529.py:6: DtypeWarning: Columns (0,7,8,9,11,12,18,20,22,31,32,33,34,35,36,37,41,43,45,53,54,55,57,58,59,65,66,68,72,73,74,75,76,78,79,80,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   perchase_df = pd.read_csv('./data/한국산림복지진흥원_산림복지전문업지원시스템 결제정보_20210630.csv', encoding='utf-8')

# %%
# 모든 컬럼 출력 설정
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_seq_items', None)

# %%
# food_df 데이터 확인
food_df.head()
# Out:
#                   식품코드      식품명 데이터구분코드 데이터구분명  식품기원코드       식품기원명  식품대분류코드  \
# 0  D101-004160000-0001  국밥_돼지머리       D     음식       1  가정식(분석 함량)        1
# 1  D101-004310000-0001  국밥_순대국밥       D     음식       1  가정식(분석 함량)        1
# 2  D101-004500000-0001   국밥_콩나물       D     음식       1  가정식(분석 함량)        1
# 3  D101-006000000-0001      기장밥       D     음식       1  가정식(분석 함량)        1
# 4  D101-007000000-0001       김밥       D     음식       1  가정식(분석 함량)        1
#
#   식품대분류명  대표식품코드 대표식품명  식품중분류코드 식품중분류명   식품소분류코드 식품소분류명  식품세분류코드 식품세분류명  \
# 0     밥류    1004    국밥   100416   돼지머리  10041600   해당없음        0   해당없음
# 1     밥류    1004    국밥   100431   순대국밥  10043100   해당없음        0   해당없음
# 2     밥류    1004    국밥   100450    콩나물  10045000   해당없음        0   해당없음
# 3     밥류    1006   기장밥   100600   해당없음  10060000   해당없음        0   해당없음
# 4     밥류    1007    김밥   100700   해당없음  10070000   해당없음        0   해당없음
#
#   영양성분함량기준량  에너지(kcal)  수분(g)  단백질(g)  지방(g)  회분(g)  탄수화물(g)  당류(g)  식이섬유(g)  \
# 0      100g        137   71.6    6.70   5.16   0.63    15.94   0.16      0.7
# 1      100g         75   83.7    3.17   2.28   0.48    10.38   0.17      1.3
# 2      100g         52   86.8    1.45   0.24   0.56    10.93   0.00      1.2
# 3      100g        166   59.1    3.44   0.57   0.15    36.77   0.00      1.5
# 4      100g        140   69.5    4.84   4.55   1.11    19.98   0.00      1.4
#
#    칼슘(mg)  철(mg)  인(mg)  칼륨(mg)  나트륨(mg)  비타민A(μg RAE)  레티놀(μg)  베타카로틴(μg)  \
# 0     9.0   0.24   24.0    47.0    181.0           5.0      0.0       61.0
# 1     9.0   0.67   31.0    34.0    126.0           5.0      0.0       55.0
# 2     6.0   0.18   16.0    42.0    172.0           2.0      0.0       22.0
# 3     4.0   0.33   28.0    25.0      1.0           0.0      0.0        0.0
# 4    36.0   0.30   55.0   118.0    307.0         113.0      3.0     1318.0
#
#    티아민(mg)  리보플라빈(mg)  니아신(mg)  비타민 C(mg)  비타민 D(μg)  콜레스테롤(mg)  포화지방산(g)  \
# 0    0.090      0.053    0.000       0.04        0.0      23.82      1.47
# 1    0.062      0.024    0.000       0.21        0.0      48.69      1.26
# 2    0.140      0.022    0.173       1.26        0.0       0.00      0.12
# 3    0.000      0.005    0.205       0.29        0.0       0.00      0.08
# 4    0.157      0.043    0.674       3.76        0.0      19.30      1.10
#
#    트랜스지방산(g)  니코틴산(mg)  니코틴아마이드(mg)  비오틴(μg)  비타민 B6 / 피리독신(mg)  비타민 B12(μg)  \
# 0       0.03       NaN          NaN      NaN                NaN         0.13
# 1       0.01       NaN          NaN      NaN                NaN         0.00
# 2       0.00       NaN          NaN      NaN                NaN         0.00
# 3       0.00       NaN          NaN      NaN                NaN         0.00
# 4       0.02       NaN          NaN      NaN                NaN         0.87
#
#    엽산(μg DFE)  콜린(mg)  판토텐산(mg)  비타민 D2(μg)  비타민 D3(μg)  비타민 E(mg α-TE)  \
# 0        5.30     NaN       NaN         NaN         NaN             NaN
# 1        6.59     NaN       NaN         NaN         NaN             NaN
# 2        5.27     NaN       NaN         NaN         NaN             NaN
# 3        2.52     NaN       NaN         NaN         NaN             NaN
# 4       21.47     NaN       NaN         NaN         NaN             NaN
#
#    알파 토코페롤(mg)  베타 토코페롤(mg)  감마 토코페롤(mg)  델타 토코페롤(mg)  알파 토코트리에놀(mg)  \
# 0          NaN          NaN          NaN          NaN            NaN
# 1          NaN          NaN          NaN          NaN            NaN
# 2          NaN          NaN          NaN          NaN            NaN
# 3          NaN          NaN          NaN          NaN            NaN
# 4          NaN          NaN          NaN          NaN            NaN
#
#    베타 토코트리에놀(mg)  감마 토코트리에놀(mg)  델타 토코트리에놀(mg)  비타민 K(μg)  비타민 K1(μg)  \
# 0            NaN            NaN            NaN        NaN         NaN
# 1            NaN            NaN            NaN        NaN         NaN
# 2            NaN            NaN            NaN        NaN         NaN
# 3            NaN            NaN            NaN        NaN         NaN
# 4            NaN            NaN            NaN        NaN         NaN
#
#    비타민 K2(μg)  갈락토오스(g)  과당(g)  당알콜(g)  맥아당(g)  알룰로오스(g)  에리스리톨(g)  유당(g)  \
# 0         NaN       NaN   0.16     NaN     0.0       NaN       NaN    0.0
# 1         NaN       NaN   0.17     NaN     0.0       NaN       NaN    0.0
# 2         NaN       NaN   0.00     NaN     0.0       NaN       NaN    0.0
# 3         NaN       NaN   0.00     NaN     0.0       NaN       NaN    0.0
# 4         NaN       NaN   0.00     NaN     0.0       NaN       NaN    0.0
#
#    자당(g)  타가토스(g)  포도당(g)  불포화지방산(g)  EPA와 DHA의 합(mg)  \
# 0    0.0      NaN     0.0        NaN              NaN
# 1    0.0      NaN     0.0        NaN              NaN
# 2    0.0      NaN     0.0        NaN              NaN
# 3    0.0      NaN     0.0        NaN              NaN
# 4    0.0      NaN     0.0        NaN              NaN
#
#    가돌레산(20:1) / 에이코센산(20:1)(mg)  감마 리놀렌산(18:3(n-6))(mg)  네르본산(24:1)(mg)  \
# 0                          30.0                     0.0             NaN
# 1                          10.0                     0.0             NaN
# 2                           0.0                     0.0             NaN
# 3                           0.0                     0.0             NaN
# 4                          20.0                     0.0             NaN
#
#    도코사디에노산(22:2)(mg)  도코사펜타에노산/토코사펜타엔산(22:5(n-3))(mg)  \
# 0                NaN                              0.0
# 1                NaN                              0.0
# 2                NaN                              0.0
# 3                NaN                              0.0
# 4                NaN                              0.0
#
#    DHA / 도코사헥사에노산/도코사헥사엔산(22:6(n-3))(mg)  디호모리놀렌산/에이코사트리에노산(20:3(n-3))(mg)  \
# 0                                    0.0                               NaN
# 1                                    0.0                               NaN
# 2                                    0.0                               NaN
# 3                                    0.0                               NaN
# 4                                   10.0                               NaN
#
#    라우르산(12:0)(mg)  리그노세르산(24:0)(mg)  리놀레산(18:2(n-6))(g)  미리스톨레산(14:1)(mg)  \
# 0            10.0               NaN                0.51               0.0
# 1             0.0               NaN                0.24               0.0
# 2             0.0               NaN                0.25               0.0
# 3             0.0               NaN                0.10               0.0
# 4             0.0               NaN                1.20               0.0
#
#    미리스트산(14:0)(mg)  박센산(18:1(n-7))(mg)  베헨산(22:0)(mg)  부티르산(4:0)(mg)  \
# 0             70.0               180.0            NaN            0.0
# 1             50.0                60.0            NaN            0.0
# 2              0.0                10.0            NaN            0.0
# 3             10.0                 0.0            NaN            0.0
# 4             30.0                90.0            NaN            0.0
#
#    스테아르산(18:0)(mg)  스테아리돈산(18:4(n-3))(mg)  아라키돈산(20:4(n-6))(mg)  \
# 0            370.0                    NaN                   0.0
# 1            470.0                    NaN                   0.0
# 2             30.0                    NaN                   0.0
# 3             10.0                    NaN                   0.0
# 4            320.0                    NaN                   0.0
#
#    아라키드산(20:0)(mg)  알파 리놀렌산(18:3(n-3))(g)  에루크산(22:1)(mg)  \
# 0             10.0                   0.02             NaN
# 1             10.0                   0.01             NaN
# 2              0.0                   0.02             NaN
# 3              0.0                   0.01             NaN
# 4             10.0                   0.07             NaN
#
#    에이코사디에노산(20:2(n-6))(mg)  에이코사트리에노산(20:3(n-6))(mg)  \
# 0                     20.0                       0.0
# 1                     10.0                      30.0
# 2                      0.0                       0.0
# 3                      0.0                       0.0
# 4                     10.0                      20.0
#
#    EPA / 에이코사펜타에노산(20:5(n-3))(mg)  오메가3 지방산(g)  오메가6 지방산(g)  \
# 0                             0.0          NaN          NaN
# 1                             0.0          NaN          NaN
# 2                             0.0          NaN          NaN
# 3                             0.0          NaN          NaN
# 4                            20.0          NaN          NaN
#
#    올레산(18:1(n-9))(mg)  카프로산(6:0)(mg)  카프르산(10:0)(mg)  카프릴산(8:0)(mg)  \
# 0              1670.0            0.0             0.0            0.0
# 1               770.0            0.0             0.0            0.0
# 2               160.0            0.0             0.0            0.0
# 3                50.0            0.0             0.0            0.0
# 4              1510.0            0.0             0.0            0.0
#
#    트라이데칸산(13:0)(mg)  트랜스 리놀레산(18:2t)(mg)  트랜스 리놀렌산(18:3t)(mg)  \
# 0               NaN                 10.0                  0.0
# 1               NaN                  0.0                  0.0
# 2               NaN                  0.0                  0.0
# 3               NaN                  0.0                  0.0
# 4               NaN                 10.0                  0.0
#
#    트랜스 올레산(18:1(n-9t)(mg)  트리코산산(23:0)(mg)  팔미톨레산(16:1)(mg)  팔미트산(16:0)(mg)  \
# 0                    10.0              NaN            160.0          1000.0
# 1                    10.0              NaN             40.0           730.0
# 2                     0.0              NaN              0.0            80.0
# 3                     0.0              NaN              0.0            70.0
# 4                    10.0              NaN             50.0           740.0
#
#    펜타데칸산(15:0)(mg)  헨에이코산산(21:0)(mg)  헵타데센산(17:1)(mg)  헵타데칸산(17:0)(mg)  \
# 0              NaN               NaN              NaN              NaN
# 1              NaN               NaN              NaN              NaN
# 2              NaN               NaN              NaN              NaN
# 3              NaN               NaN              NaN              NaN
# 4              NaN               NaN              NaN              NaN
#
#    구리(μg)  마그네슘(mg)  망간(mg)  몰리브덴(μg)  불소(mg)  셀레늄(μg)  아연(mg)  염소(mg)  \
# 0    60.0      5.06    0.06       NaN     NaN     3.25    0.39     NaN
# 1    60.0      5.80    0.08       NaN     NaN     4.39    0.71     NaN
# 2    20.0      5.45    0.11       NaN     NaN     2.24    0.36     NaN
# 3   120.0      6.77    0.26       NaN     NaN     0.76    0.82     NaN
# 4   170.0     12.33    0.25       NaN     NaN     6.56    0.52     NaN
#
#    요오드(μg)  크롬(μg)  아미노산(mg)  필수아미노산(mg)  비필수아미노산(mg)  글루탐산(mg)  글라이신(mg)  \
# 0      NaN     NaN   4709.09         NaN          NaN    814.92    688.70
# 1      NaN     NaN   3845.25         NaN          NaN    674.88    351.25
# 2      NaN     NaN   1089.39         NaN          NaN    215.34     43.91
# 3      NaN     NaN   2705.95         NaN          NaN    577.74    124.88
# 4      NaN     NaN   5029.73         NaN          NaN    838.52    261.54
#
#    라이신(mg)  류신(mg)  메티오닌(mg)  발린(mg)  세린(mg)  시스테인(mg)  아르기닌(mg)  아스파르트산(mg)  \
# 0   285.08  306.81     40.50  169.28  204.19     26.41    339.75      392.82
# 1   270.41  314.96     21.08  165.18  191.58     29.45    275.55      358.71
# 2    42.67  116.09      1.48   45.34   59.09     34.96     68.61      167.27
# 3    87.10  297.21     17.24  153.76  153.17     25.29    198.02      259.63
# 4   318.59  443.53    106.81  310.85  260.75     48.34    394.28      489.40
#
#    알라닌(mg)  이소류신(mg)  타우린(mg)  트레오닌(mg)  트립토판(mg)  티로신(mg)  페닐알라닌(mg)  \
# 0   368.60    125.49      NaN    154.72       NaN    94.20     159.89
# 1   259.51    126.52      NaN    160.67       NaN   111.98     158.74
# 2    59.56     37.12      NaN     41.24       NaN    47.92      59.40
# 3   196.87    119.03      NaN     96.37       NaN    64.23     158.53
# 4   323.84    242.01      NaN    229.52       NaN   159.09     251.51
#
#    프롤린(mg)  히스티딘(mg)  카페인(mg)  토코페롤(mg)  토코트리에놀(mg)  출처코드       출처명  \
# 0   468.09     69.65      NaN      0.30        0.04     3  식품의약품안전처
# 1   299.07     75.73      NaN      0.33        0.06     3  식품의약품안전처
# 2    25.18     24.21      NaN      0.33        0.04     3  식품의약품안전처
# 3   141.32     35.60      NaN      0.22        0.21     3  식품의약품안전처
# 4   227.79    123.36      NaN      0.98        0.09     3  식품의약품안전처
#
#    1인(회)분량 참고량  식품중량   업체명  데이터생성방법코드 데이터생성방법명     데이터생성일자    데이터기준일자
# 0          NaN  900g  해당없음          1       분석  2017-12-31 2025-12-29
# 1          NaN  900g  해당없음          1       분석  2017-12-31 2025-12-29
# 2          NaN  780g  해당없음          1       분석  2018-12-31 2025-12-29
# 3          NaN  200g  해당없음          1       분석  2017-12-31 2025-12-29
# 4          NaN  230g  해당없음          1       분석  2018-12-31 2025-12-29

# %%
with pd.option_context('display.max_seq_items', None):
    print(food_df.columns)
# Out:
# Index(['식품코드', '식품명', '데이터구분코드', '데이터구분명', '식품기원코드', '식품기원명', '식품대분류코드',
#        '식품대분류명', '대표식품코드', '대표식품명', '식품중분류코드', '식품중분류명', '식품소분류코드', '식품소분류명',
#        '식품세분류코드', '식품세분류명', '영양성분함량기준량', '에너지(kcal)', '수분(g)', '단백질(g)',
#        '지방(g)', '회분(g)', '탄수화물(g)', '당류(g)', '식이섬유(g)', '칼슘(mg)', '철(mg)',
#        '인(mg)', '칼륨(mg)', '나트륨(mg)', '비타민A(μg RAE)', '레티놀(μg)', '베타카로틴(μg)',
#        '티아민(mg)', '리보플라빈(mg)', '니아신(mg)', '비타민 C(mg)', '비타민 D(μg)',
#        '콜레스테롤(mg)', '포화지방산(g)', '트랜스지방산(g)', '니코틴산(mg)', '니코틴아마이드(mg)',
#        '비오틴(μg)', '비타민 B6 / 피리독신(mg)', '비타민 B12(μg)', '엽산(μg DFE)', '콜린(mg)',
#        '판토텐산(mg)', '비타민 D2(μg)', '비타민 D3(μg)', '비타민 E(mg α-TE)', '알파 토코페롤(mg)',
#        '베타 토코페롤(mg)', '감마 토코페롤(mg)', '델타 토코페롤(mg)', '알파 토코트리에놀(mg)',
#        '베타 토코트리에놀(mg)', '감마 토코트리에놀(mg)', '델타 토코트리에놀(mg)', '비타민 K(μg)',
#        '비타민 K1(μg)', '비타민 K2(μg)', '갈락토오스(g)', '과당(g)', '당알콜(g)', '맥아당(g)',
#        '알룰로오스(g)', '에리스리톨(g)', '유당(g)', '자당(g)', '타가토스(g)', '포도당(g)',
#        '불포화지방산(g)', 'EPA와 DHA의 합(mg)', '가돌레산(20:1) / 에이코센산(20:1)(mg)',
#        '감마 리놀렌산(18:3(n-6))(mg)', '네르본산(24:1)(mg)', '도코사디에노산(22:2)(mg)',
#        '도코사펜타에노산/토코사펜타엔산(22:5(n-3))(mg)',
#        'DHA / 도코사헥사에노산/도코사헥사엔산(22:6(n-3))(mg)',
#        '디호모리놀렌산/에이코사트리에노산(20:3(n-3))(mg)', '라우르산(12:0)(mg)',
#        '리그노세르산(24:0)(mg)', '리놀레산(18:2(n-6))(g)', '미리스톨레산(14:1)(mg)',
#        '미리스트산(14:0)(mg)', '박센산(18:1(n-7))(mg)', '베헨산(22:0)(mg)',
#        '부티르산(4:0)(mg)', '스테아르산(18:0)(mg)', '스테아리돈산(18:4(n-3))(mg)',
#        '아라키돈산(20:4(n-6))(mg)', '아라키드산(20:0)(mg)', '알파 리놀렌산(18:3(n-3))(g)',
#        '에루크산(22:1)(mg)', '에이코사디에노산(20:2(n-6))(mg)', '에이코사트리에노산(20:3(n-6))(mg)',
#        'EPA / 에이코사펜타에노산(20:5(n-3))(mg)', '오메가3 지방산(g)', '오메가6 지방산(g)',
#        '올레산(18:1(n-9))(mg)', '카프로산(6:0)(mg)', '카프르산(10:0)(mg)',
#        '카프릴산(8:0)(mg)', '트라이데칸산(13:0)(mg)', '트랜스 리놀레산(18:2t)(mg)',
#        '트랜스 리놀렌산(18:3t)(mg)', '트랜스 올레산(18:1(n-9t)(mg)', '트리코산산(23:0)(mg)',
#        '팔미톨레산(16:1)(mg)', '팔미트산(16:0)(mg)', '펜타데칸산(15:0)(mg)',
#        '헨에이코산산(21:0)(mg)', '헵타데센산(17:1)(mg)', '헵타데칸산(17:0)(mg)', '구리(μg)',
#        '마그네슘(mg)', '망간(mg)', '몰리브덴(μg)', '불소(mg)', '셀레늄(μg)', '아연(mg)',
#        '염소(mg)', '요오드(μg)', '크롬(μg)', '아미노산(mg)', '필수아미노산(mg)', '비필수아미노산(mg)',
#        '글루탐산(mg)', '글라이신(mg)', '라이신(mg)', '류신(mg)', '메티오닌(mg)', '발린(mg)',
#        '세린(mg)', '시스테인(mg)', '아르기닌(mg)', '아스파르트산(mg)', '알라닌(mg)', '이소류신(mg)',
#        '타우린(mg)', '트레오닌(mg)', '트립토판(mg)', '티로신(mg)', '페닐알라닌(mg)', '프롤린(mg)',
#        '히스티딘(mg)', '카페인(mg)', '토코페롤(mg)', '토코트리에놀(mg)', '출처코드', '출처명',
#        '1인(회)분량 참고량', '식품중량', '업체명', '데이터생성방법코드', '데이터생성방법명', '데이터생성일자',
#        '데이터기준일자'],
#       dtype='object')

# %%
import pandas as pd

with pd.option_context('display.max_rows', None):
    print(food_df['영양성분함량기준량'].dtypes)
# Out:
# object

# %%
import pandas as pd
import numpy as np
import re

def reduce_and_evaluate_food_data(food_df):
    # ---------------------------------------------------------
    # 1. 데이터 전처리 (컬럼 추출 및 형변환)
    # ---------------------------------------------------------
    
    # 분석용 핵심 컬럼 추출 (원본 보호를 위해 copy)
    core_columns = [
        '식품코드', '업체명', '식품명', '대표식품명', '식품대분류명', '식품중분류명', '영양성분함량기준량',
        '에너지(kcal)', '단백질(g)', '지방(g)', '탄수화물(g)', 
        '당류(g)', '식이섬유(g)', '나트륨(mg)', '칼륨(mg)', '콜레스테롤(mg)', 
        '포화지방산(g)', '트랜스지방산(g)',  '데이터기준일자'
    ]
    df_core = food_df[core_columns].copy()
    
    # 기준량 데이터 정제 (문자열에서 숫자만 추출 후 변환)
    df_core['영양성분함량기준량'] = df_core['영양성분함량기준량'].astype(str).str.extract(r'(\d+\.?\d*)')
    df_core['영양성분함량기준량'] = pd.to_numeric(df_core['영양성분함량기준량'], errors='coerce')
    
    # 영양성분 컬럼 숫자형 변환
    numeric_cols = [
        '에너지(kcal)', '단백질(g)', '지방(g)', '탄수화물(g)', 
        '당류(g)', '식이섬유(g)', '나트륨(mg)', '칼륨(mg)', '콜레스테롤(mg)', 
        '포화지방산(g)', '트랜스지방산(g)', 
    ]
    for col in numeric_cols:
        df_core[col] = pd.to_numeric(df_core[col], errors='coerce')
    
    # 결측치 0 대체 및 컬럼명 직관화
    df_core.fillna(0, inplace=True)
    df_core = df_core.rename(columns={'영양성분함량기준량': '기준량(g)'})
    
    # ---------------------------------------------------------
    # 2. 영양학적 지표 계산 (분모가 0일 때의 오류 방지를 위해 np.where 사용)
    # ---------------------------------------------------------
    
    # [2-1] 에너지 밀도 (1g당 열량)
    df_core['에너지밀도(kcal/g)'] = np.where(
        df_core['기준량(g)'] > 0, 
        df_core['에너지(kcal)'] / df_core['기준량(g)'], 
        0
    )
    
    # [2-2] 3대 영양소 에너지 비율 (%) (탄수화물 4kcal, 단백질 4kcal, 지방 9kcal 기준)
    df_core['탄수화물_에너지비율(%)'] = np.where(df_core['에너지(kcal)'] > 0, (df_core['탄수화물(g)'] * 4 / df_core['에너지(kcal)']) * 100, 0)
    df_core['단백질_에너지비율(%)'] = np.where(df_core['에너지(kcal)'] > 0, (df_core['단백질(g)'] * 4 / df_core['에너지(kcal)']) * 100, 0)
    df_core['지방_에너지비율(%)'] = np.where(df_core['에너지(kcal)'] > 0, (df_core['지방(g)'] * 9 / df_core['에너지(kcal)']) * 100, 0)
    
    # [2-3] 세부 영양 품질 지표
    # 단백질 INQ (하루 권장량: 에너지 2,000kcal, 단백질 55g 기준)
    # 1.0 이상이면 단백질이 충분히 포함된 식품으로 간주
    df_core['단백질_INQ'] = np.where(
        df_core['에너지(kcal)'] > 0,
        (df_core['단백질(g)'] / 55) / (df_core['에너지(kcal)'] / 2000),
        0
    )
    
    # 당류 비율 (전체 탄수화물 중 단순당 비중)
    df_core['당류비율(%)'] = np.where(
        df_core['탄수화물(g)'] > 0,
        (df_core['당류(g)'] / df_core['탄수화물(g)']) * 100,
        0
    )
    
    # 나트륨-칼륨 비율 (수분 저류 예측 지표, 1.0에 가까울수록 균형)
    df_core['나트륨_칼륨_비율'] = np.where(
        df_core['칼륨(mg)'] > 0,
        df_core['나트륨(mg)'] / df_core['칼륨(mg)'],
        0
    )
    
    # ---------------------------------------------------------
    # 3. 데이터 후처리
    # ---------------------------------------------------------
    
    # 무한대 값(inf) 0 치환 및 소수점 둘째 자리 반올림
    df_core.replace([np.inf, -np.inf], 0, inplace=True)
    
    return df_core.round(2)

# 실행
food_cleaned_df = reduce_and_evaluate_food_data(food_df)
food_cleaned_df.head()
# Out:
#                   식품코드   업체명      식품명 대표식품명 식품대분류명 식품중분류명  기준량(g)  에너지(kcal)  \
# 0  D101-004160000-0001  해당없음  국밥_돼지머리    국밥     밥류   돼지머리     100        137
# 1  D101-004310000-0001  해당없음  국밥_순대국밥    국밥     밥류   순대국밥     100         75
# 2  D101-004500000-0001  해당없음   국밥_콩나물    국밥     밥류    콩나물     100         52
# 3  D101-006000000-0001  해당없음      기장밥   기장밥     밥류   해당없음     100        166
# 4  D101-007000000-0001  해당없음       김밥    김밥     밥류   해당없음     100        140
#
#    단백질(g)  지방(g)  탄수화물(g)  당류(g)  식이섬유(g)  나트륨(mg)  칼륨(mg)  콜레스테롤(mg)  \
# 0    6.70   5.16    15.94   0.16      0.7    181.0    47.0      23.82
# 1    3.17   2.28    10.38   0.17      1.3    126.0    34.0      48.69
# 2    1.45   0.24    10.93   0.00      1.2    172.0    42.0       0.00
# 3    3.44   0.57    36.77   0.00      1.5      1.0    25.0       0.00
# 4    4.84   4.55    19.98   0.00      1.4    307.0   118.0      19.30
#
#    포화지방산(g)  트랜스지방산(g)    데이터기준일자  에너지밀도(kcal/g)  탄수화물_에너지비율(%)  단백질_에너지비율(%)  \
# 0      1.47       0.03 2025-12-29           1.37          46.54         19.56
# 1      1.26       0.01 2025-12-29           0.75          55.36         16.91
# 2      0.12       0.00 2025-12-29           0.52          84.08         11.15
# 3      0.08       0.00 2025-12-29           1.66          88.60          8.29
# 4      1.10       0.02 2025-12-29           1.40          57.09         13.83
#
#    지방_에너지비율(%)  단백질_INQ  당류비율(%)  나트륨_칼륨_비율
# 0        33.90     1.78     1.00       3.85
# 1        27.36     1.54     1.64       3.71
# 2         4.15     1.01     0.00       4.10
# 3         3.09     0.75     0.00       0.04
# 4        29.25     1.26     0.00       2.60

# %%
# shop_df 데이터 확인
shop_df.head()
# Out:
#    개방자치단체코드                    관리번호        인허가번호 영업상태명        폐업일자 데이터갱신구분  \
# 0   3150000  3150000-101-1976-04186  19760076001    영업         NaN       I
# 1   3150000  3150000-101-1976-04242  19760076005    폐업  1996-08-12       I
# 2   3150000  3150000-101-1979-04232  19790076035    폐업  2011-02-11       I
# 3   3150000  3150000-101-1979-05418  19790076013    영업         NaN       I
# 4   3150000  3150000-101-1980-05683  19800076017    폐업  2007-04-05       I
#
#         업소명                               도로명주소                         소재지주소  \
# 0     공항뚝배기      서울특별시 강서구 공항대로 15, 지하 1층 (공항동)  서울특별시 강서구 공항동 45-18 (지하 1층)
# 1       신흥각                                 NaN          서울특별시 강서구 화곡동 920-6
# 2       오미각                                 NaN         서울특별시 강서구 염창동 282-20
# 3       외갓집  서울특별시 강서구 우장산로16길 44, 1층 (화곡동, 6동)  서울특별시 강서구 화곡동 997-9 (지상 1층)
# 4  정청호제주똥돼지                                 NaN        서울특별시 강서구 방화동 620-192
#
#    영업상태코드         전화번호        신청일자        지정일자      지정취소일자  \
# 0       1  226623171.0  2008-07-09  2008-07-09  2008-07-08
# 1       2   26024121.0  1976-02-28  1976-02-28  1996-08-12
# 2       2   26525106.0  2004-06-01  2004-07-05  2005-02-18
# 3       1  226954685.0  2002-03-15  2002-04-12  2016-11-03
# 4       2   26646968.0  2002-03-15  2002-04-12  2007-04-05
#
#                 지정취소사유  불가일자  불가사유 음식의유형   주된음식종류       재지정일자  \
# 0                 지정취소   NaN   NaN   NaN      NaN  2012-11-30
# 1                 자진폐업   NaN   NaN   NaN       한식         NaN
# 2              영업자지위승계   NaN   NaN   NaN      자장면         NaN
# 3  2016년 모범음식점 평가기준 미달   NaN   NaN    한식     소,등심  2015-11-18
# 4                 폐업민원   NaN   NaN   NaN  와인숙성생고기  2004-07-05
#
#                데이터갱신시점               최종수정시점
# 0  2025-12-15 16:21:53  2021-04-28 16:35:56
# 1  2025-12-15 16:21:53  2014-02-17 14:20:51
# 2  2025-12-15 16:21:53  2009-03-10 10:48:21
# 3  2025-12-15 16:21:53  2021-05-14 13:01:35
# 4  2025-12-15 16:21:53  2007-07-14 13:29:58

# %%
with pd.option_context('display.max_seq_items', None):
    print(shop_df.columns)
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가번호', '영업상태명', '폐업일자', '데이터갱신구분', '업소명', '도로명주소',
#        '소재지주소', '영업상태코드', '전화번호', '신청일자', '지정일자', '지정취소일자', '지정취소사유', '불가일자',
#        '불가사유', '음식의유형', '주된음식종류', '재지정일자', '데이터갱신시점', '최종수정시점'],
#       dtype='object')

# %%
import pandas as pd

def reduce_and_clean_shop_data(shop_df):
    # ---------------------------------------------------------
    # 1. 필요 데이터 추출 (원본 보호를 위해 copy)
    # ---------------------------------------------------------
    core_columns = [
        '인허가번호', '업소명', '영업상태코드', '도로명주소', 
        '소재지주소', '전화번호', '음식의유형', '주된음식종류'
    ]
    df_core = shop_df[core_columns].copy()
    
    # ---------------------------------------------------------
    # 2. 영업상태 필터링 (1, 2: 영업 중)
    # ---------------------------------------------------------
    # 타입 혼재(숫자/문자) 오류를 방지하기 위해 문자열 변환 후 필터링
    df_core = df_core[df_core['영업상태코드'].astype(str).isin(['1', '2'])]
    
    # ---------------------------------------------------------
    # 3. 결측치 대체 및 텍스트 정제
    # ---------------------------------------------------------
    # 텍스트형 결측치(NaN)를 분석 목적에 맞게 기본값으로 치환
    fill_dict = {
        '도로명주소': '',
        '소재지주소': '',
        '전화번호': '',
        '음식의유형': '',
        '주된음식종류': ''
    }
    df_core.fillna(fill_dict, inplace=True)
    
    # 문자열 컬럼의 불필요한 양옆 공백 제거
    text_cols = df_core.select_dtypes(include=['object']).columns
    for col in text_cols:
        df_core[col] = df_core[col].astype(str).str.strip()

    # 전화번호 컬럼에서 판다스 실수형 변환으로 인해 생긴 '.0' 꼬리표 제거
    # 정규표현식 r'\.0$'는 '문자열의 끝에 있는 .0'만 타겟팅하여 빈 문자열로 바꿉니다.
    df_core['전화번호'] = df_core['전화번호'].str.replace(r'\.0$', '', regex=True)
        
    return df_core

# 실행
processed_shop_df = reduce_and_clean_shop_data(shop_df)
processed_shop_df.head()
# Out:
#          인허가번호       업소명  영업상태코드                               도로명주소  \
# 0  19760076001     공항뚝배기       1      서울특별시 강서구 공항대로 15, 지하 1층 (공항동)
# 1  19760076005       신흥각       2
# 2  19790076035       오미각       2
# 3  19790076013       외갓집       1  서울특별시 강서구 우장산로16길 44, 1층 (화곡동, 6동)
# 4  19800076017  정청호제주똥돼지       2
#
#                          소재지주소       전화번호 음식의유형   주된음식종류
# 0  서울특별시 강서구 공항동 45-18 (지하 1층)  226623171
# 1          서울특별시 강서구 화곡동 920-6   26024121             한식
# 2         서울특별시 강서구 염창동 282-20   26525106            자장면
# 3  서울특별시 강서구 화곡동 997-9 (지상 1층)  226954685    한식     소,등심
# 4        서울특별시 강서구 방화동 620-192   26646968        와인숙성생고기

# %%
# perchase_df 데이터 확인
perchase_df.head()
# Out:
#       상품(ID)  시설대분류코드(FCLT_LRCLS_CD)  시설용도구분코드(FCLT_PRPSE_TPCD)  \
# 0  G20160727                     7.0                        1.0
# 1  G20160727                     7.0                        1.0
# 2  G20160727                     7.0                        1.0
# 3  G20160727                     7.0                        1.0
# 4  G20160727                     3.0                        1.0
#
#    시즌구분코드(SSN_TPCD)  일자구분코드(DT_TPCD)  위약규정일수(PNLT_RGLTN_DCNT)  \
# 0               1.0              1.0                      5.0
# 1               1.0              2.0                      5.0
# 2               2.0              1.0                      5.0
# 3               2.0              2.0                      5.0
# 4               1.0              1.0                      0.0
#
#    공제율비(DDCTN_RATE)      등록일시1(RGTER_ID) 최종수정일시1(LAST_UPDT_DTM)  \
# 0              30.0  2020-06-01 21:09:00    2020-06-01 21:09:00
# 1              30.0  2020-06-01 21:09:00    2020-06-01 21:09:00
# 2              30.0  2020-06-01 21:09:00    2020-06-01 21:09:00
# 3              30.0  2020-06-01 21:09:00    2020-06-01 21:09:00
# 4              20.0  2018-06-22 11:21:00                    NaN
#
#   유효여부(VLDTY_YN)  취소금액(CANCELAMT) 취소사유(CANCELMSG) 부분취소구분(PARTIALCANCELCODE)  \
# 0              Y              NaN             NaN                       NaN
# 1              Y           4000.0           취소 성공                         Y
# 2              Y           4000.0           취소 성공                         Y
# 3              Y           4000.0           취소 성공                         Y
# 4              Y           4000.0           취소 성공                         Y
#
#    취소결과코드(CANCELRESULTCODE)  결제순번(STTLM_SEQ)  결제순번2(STTLM_SEQ)  \
# 0                       NaN              NaN               1.0
# 1                    2001.0              NaN               1.0
# 2                    2001.0              NaN               1.0
# 3                    2001.0              NaN               1.0
# 4                    2001.0              NaN               1.0
#
#    결제금액(STTLM_AMT)  위약금금액(PNLT_AMT) 결제만기일시(STTLM_MT_DTM)  \
# 0          58000.0              NaN                  NaN
# 1          10000.0              NaN                  NaN
# 2          10000.0              NaN                  NaN
# 3          89000.0              NaN                  NaN
# 4          10000.0              NaN                  NaN
#
#   결제완료일시(STTLM_CMPLE_DTM) 결제상태코드(STTLM_STCD)     등록일시2(RGSTN_DTM)  \
# 0     2013-05-31 08:50:00               3001  2013-05-31 08:48:00
# 1     2013-06-02 22:33:00               4000  2013-06-02 22:26:00
# 2     2013-05-20 11:14:00               3001  2013-05-20 11:12:00
# 3     2013-05-18 11:00:00               3001  2013-05-18 10:58:00
# 4     2013-05-20 10:32:00               3001  2013-05-20 10:30:00
#
#   최종수정일시2(LAST_UPDT_DTM) 유효여부2(VLDTY_YN)  환불테이블순번(RFNDM_TABLE_SEQ)  \
# 0                    NaN               Y                   20581.0
# 1                    NaN               Y                   20582.0
# 2                    NaN               Y                   20583.0
# 3                    NaN               Y                   20588.0
# 4                    NaN               Y                   20589.0
#
#    환불유형코드(RFNDM_TPE_CD)  부서ID(DPRTM_ID)  예약순번(RSRVT_SEQ)  결제순번3(STTLM_SEQ)  \
# 0                   1.0           101.0             11.0               3.0
# 1                   1.0           101.0             12.0               3.0
# 2                   1.0           101.0             12.0               3.0
# 3                   1.0           101.0              3.0               2.0
# 4                   1.0           101.0              3.0               2.0
#
#    환불금액(RFNDM_AMT)  위약금금액2(PNLT_AMT) 환불사유(RFNDM_RSN) 환불요청일시(RFNDM_RQUST_DTM)  \
# 0           1500.0               0.0             NaN     2013-11-28 23:59:00
# 1           3000.0               0.0             NaN     2013-11-28 23:59:00
# 2           3000.0               0.0             NaN     2013-11-28 23:59:00
# 3           4000.0               0.0             NaN     2013-11-29 23:59:00
# 4          32000.0               0.0             NaN     2013-12-02 23:59:00
#
#   환불완료일시(RFNDM_CMPLE_DTM)     등록일시3(RGSTN_DTM) 최종수정일시3(LAST_UPDT_DTM)  \
# 0                     NaN  2013-11-28 16:05:00                    NaN
# 1                     NaN  2013-11-28 16:05:00                    NaN
# 2                     NaN  2013-11-28 16:05:00                    NaN
# 3                     NaN  2013-11-29 14:17:00                    NaN
# 4                     NaN  2013-11-29 14:31:00                    NaN
#
#   유효여부3(VLDTY_YN) 결제수단(PAYMETHOD)  결제상품개수(GOODSCNT)  결제상품금액(AMT)  \
# 0               Y           VBANK               1.0       4000.0
# 1               Y           VBANK               1.0       4000.0
# 2               Y           VBANK               1.0       4000.0
# 3               Y           VBANK               1.0       4000.0
# 4               Y           VBANK               1.0      14000.0
#
#    우편번호(BUYERPOSTNO) 가상계좌입금만료일(VBANKEXPDATE)  전문생성일시코드(EDIDATECODE)  \
# 0           302840.0     2013-06-29 00:00:00           2.010000e+13
# 1           302840.0     2013-07-15 00:00:00           2.010000e+13
# 2           302840.0     2013-07-27 00:00:00           2.010000e+13
# 3           302840.0     2013-09-09 00:00:00           2.010000e+13
# 4           302840.0     2013-09-13 00:00:00           2.010000e+13
#
#   통화구분(CURRENCY)  승인일자코드(AUTHDATECODE) 결과코드(RESULTCODE)  결제순번4(STTLM_SEQ)  \
# 0            KRW          1.310000e+11             4100               1.0
# 1            KRW          1.310000e+11             4100               1.0
# 2            KRW          1.310000e+11             4100               1.0
# 3            KRW          1.310000e+11             4100               1.0
# 4            KRW          1.310000e+11             4100               1.0
#
#    시설대분류코드2(FCLT_LRCLS_CD)  시설용도구분코드2(FCLT_PRPSE_TPCD)  시즌구분코드2(SSN_TPCD)  \
# 0                      7.0                         1.0                1.0
# 1                      7.0                         1.0                1.0
# 2                      7.0                         1.0                2.0
# 3                      7.0                         1.0                2.0
# 4                      3.0                         1.0                1.0
#
#    일자구분코드2(DT_TPCD)  위약규정일수2(PNLT_RGLTN_DCNT)  공제율비2(DDCTN_RATE)  \
# 0               1.0                       5.0               30.0
# 1               2.0                       5.0               30.0
# 2               1.0                       5.0               30.0
# 3               2.0                       5.0               30.0
# 4               1.0                       0.0               20.0
#
#        등록일시4(RGTER_ID) 최종수정일시4(LAST_UPDT_DTM) 유효여부4(VLDTY_YN)  \
# 0  2020-06-01 21:09:00    2020-06-01 21:09:00               Y
# 1  2020-06-01 21:09:00    2020-06-01 21:09:00               Y
# 2  2020-06-01 21:09:00    2020-06-01 21:09:00               Y
# 3  2020-06-01 21:09:00    2020-06-01 21:09:00               Y
# 4  2018-06-22 11:21:00                    NaN               Y
#
#    부서ID2(DPRTM_ID)    시설ID(FCLT_ID) 시설명(FCLT_NM) 시설설명(FCLT_DSCRT)  \
# 0            104.0  F01040300100445   문필마을 MC121       MC121(2인실)
# 1            104.0  F01040300100421   문필마을 MA121       MA121(2인실)
# 2            104.0  F01040300100422   문필마을 MA122       MA122(2인실)
# 3            104.0  F01040300100448   문필마을 MC124       MC124(2인실)
# 4            104.0  F01040300100446   문필마을 MC122       MC122(2인실)
#
#    시설대분류코드3(FCLT_LRCLS_CD)  시설중분류코드(FCLT_MDCLS_CD)  시설소분류코드(FCLT_SMCLS_CD)  \
# 0                      3.0                  3001.0               3001004.0
# 1                      3.0                  3001.0               3001004.0
# 2                      3.0                  3001.0               3001004.0
# 3                      3.0                  3001.0               3001004.0
# 4                      3.0                  3001.0               3001004.0
#
#    시설용도구분코드3(FCLT_PRPSE_TPCD)  시설예약구분코드(FCLT_RSRVT_TPCD)  \
# 0                         1.0                        2.0
# 1                         1.0                        2.0
# 2                         1.0                        2.0
# 3                         1.0                        2.0
# 4                         1.0                        2.0
#
#   시설이미지맵좌표(FCLT_IMAGE_MAP_CRD)      배치물품내용(PSTNG_THING_CONT)  구역명(ZONE_NM)  \
# 0                          NaN  힐링 숲 2인실 (숙박 + 식사 + 프로그램 체험)           NaN
# 1                          NaN  힐링 숲 2인실 (숙박 + 식사 + 프로그램 체험)           NaN
# 2                          NaN  힐링 숲 2인실 (숙박 + 식사 + 프로그램 체험)           NaN
# 3                          NaN  힐링 숲 2인실 (숙박 + 식사 + 프로그램 체험)           NaN
# 4                          NaN  힐링 숲 2인실 (숙박 + 식사 + 프로그램 체험)           NaN
#
#   면적단위(AREA_UNIT)  면적합계(AREA_SUM)  최소수용수(MNMM_ACCPT_CNT)  \
# 0               ㎡           46.57                    1.0
# 1               ㎡           31.86                    1.0
# 2               ㎡           31.86                    1.0
# 3               ㎡           46.57                    1.0
# 4               ㎡           46.57                    1.0
#
#    최대수용수(MXMM_ACCPT_CNT) 시설오픈일자(FCLT_OPEN_DTM) 시설폐쇄일자(FCLT_CLSNG_DTM)  \
# 0                    4.0   2016-01-01 23:59:00    2999-01-01 23:59:00
# 1                    4.0   2016-01-01 23:59:00    2999-01-01 23:59:00
# 2                    4.0   2016-01-01 23:59:00    2999-01-01 23:59:00
# 3                    4.0   2016-01-01 23:59:00    2999-01-01 23:59:00
# 4                    4.0   2016-01-01 23:59:00    2999-01-01 23:59:00
#
#   전기시설여부(ELCTY_FCLT_YN) 난방시설여부(HEAT_FCLT_YN) 난방시설유형코드(HEAT_FCLT_TPE_CD)  \
# 0                     Y                    Y                   난방시설유형코드
# 1                     Y                    Y                        NaN
# 2                     Y                    Y                        NaN
# 3                     Y                    Y                        NaN
# 4                     Y                    Y                        NaN
#
#    시설상태코드(FCLT_STCD)     등록일시5(RGSTN_DTM) 최종수정일시5(LAST_UPDT_DTM)  \
# 0                1.0  2016-08-05 20:27:00    2016-08-05 20:27:00
# 1                1.0  2016-08-05 20:27:00    2016-08-05 20:27:00
# 2                1.0  2016-08-05 20:27:00    2016-08-05 20:27:00
# 3                1.0  2016-08-05 20:27:00    2016-08-05 20:27:00
# 4                1.0  2016-08-05 20:27:00    2016-08-05 20:27:00
#
#   유효여부5(VLDTY_YN) AS-IS 자료(PRODUCT_CODE)  가로크기(FCLT_SIZE_W)  \
# 0               Y                    NaN                NaN
# 1               Y                    NaN                NaN
# 2               Y                    NaN                NaN
# 3               Y                    NaN                NaN
# 4               Y                    NaN                NaN
#
#    세로크기(FCLT_SIZE_H)  (PPL_CNT)  법정동코드(LGDNG_CD) 시도명(CTPRV_NM) 시군구명(SGNG_NM)  \
# 0                NaN        2.0       3023010100         대전광역시           대덕구
# 1                NaN        2.0       3023010100         대전광역시           대덕구
# 2                NaN        2.0       3023010100         대전광역시           대덕구
# 3                NaN        2.0       3023010100         대전광역시           대덕구
# 4                NaN        2.0       3023010100         대전광역시           대덕구
#
#   읍면동명(EMNDN_NM)  산여부(MNTN_YN)  시작주번지명(BGN_MIN_LTNMB_NM)  \
# 0            오정동             0                        36
# 1            오정동             0                       266
# 2            오정동             0                       266
# 3            오정동             0                       266
# 4            오정동             0                       267
#
#    시작부번지명(BGN_SUB_LTNMB_NM)  도로코드(ROAD_CD)  지하여부(UNDRG_YN) 건물명(BLDNG_NM)  \
# 0                        12   3.020000e+11               0           NaN
# 1                         7   3.020000e+11               0           NaN
# 2                         8   3.020000e+11               0           NaN
# 3                         9   3.020000e+11               0           NaN
# 4                         1   3.020000e+11               0           NaN
#
#   상세건물명(DTL_BLDNG_NM)  건물관리명(BLDNG_MNGME_NM)  읍면동ID(EMNDN_ID)  행정코드(ADMNS_CD)  \
# 0                 NaN           3.020000e+24                1    3.023051e+09
# 1                 NaN           3.020000e+24                1    3.023051e+09
# 2                 NaN           3.020000e+24                1    3.023051e+09
# 3                 NaN           3.020000e+24                1    3.023051e+09
# 4                 NaN           3.020000e+24                1    3.023051e+09
#
#   행정코드명(ADMNS_CD_NM)  우편번호ID(ZIPCD_ID) 기타명(ETC_NM)  공동건물여부(CPRTI_BLDNG_YN)  \
# 0                오정동            306817         NaN                       0
# 1                오정동            306818         NaN                       0
# 2                오정동            306818         NaN                       0
# 3                오정동            306818         NaN                       0
# 4                오정동            306818         NaN                       0
#
#        등록일시6(VLDTY_YN) 유효여부6(RGSTN_DTM)
# 0  2012-10-26 15:43:00                Y
# 1  2012-10-26 15:43:00                Y
# 2  2012-10-26 15:43:00                Y
# 3  2012-10-26 15:43:00                Y
# 4  2012-10-26 15:43:00                Y

# %%
with pd.option_context('display.max_seq_items', None):
    print(perchase_df.columns)
# Out:
# Index(['상품(ID)', '시설대분류코드(FCLT_LRCLS_CD)', '시설용도구분코드(FCLT_PRPSE_TPCD)',
#        '시즌구분코드(SSN_TPCD)', '일자구분코드(DT_TPCD)', '위약규정일수(PNLT_RGLTN_DCNT)',
#        '공제율비(DDCTN_RATE)', '등록일시1(RGTER_ID)', '최종수정일시1(LAST_UPDT_DTM)',
#        '유효여부(VLDTY_YN)', '취소금액(CANCELAMT)', '취소사유(CANCELMSG)',
#        '부분취소구분(PARTIALCANCELCODE)', '취소결과코드(CANCELRESULTCODE)',
#        '결제순번(STTLM_SEQ)', '결제순번2(STTLM_SEQ)', '결제금액(STTLM_AMT)',
#        '위약금금액(PNLT_AMT)', '결제만기일시(STTLM_MT_DTM)', '결제완료일시(STTLM_CMPLE_DTM)',
#        '결제상태코드(STTLM_STCD)', '등록일시2(RGSTN_DTM)', '최종수정일시2(LAST_UPDT_DTM)',
#        '유효여부2(VLDTY_YN)', '환불테이블순번(RFNDM_TABLE_SEQ)', '환불유형코드(RFNDM_TPE_CD)',
#        '부서ID(DPRTM_ID)', '예약순번(RSRVT_SEQ)', '결제순번3(STTLM_SEQ)',
#        '환불금액(RFNDM_AMT)', '위약금금액2(PNLT_AMT)', '환불사유(RFNDM_RSN)',
#        '환불요청일시(RFNDM_RQUST_DTM)', '환불완료일시(RFNDM_CMPLE_DTM)',
#        '등록일시3(RGSTN_DTM)', '최종수정일시3(LAST_UPDT_DTM)', '유효여부3(VLDTY_YN)',
#        '결제수단(PAYMETHOD)', '결제상품개수(GOODSCNT)', '결제상품금액(AMT)',
#        '우편번호(BUYERPOSTNO)', '가상계좌입금만료일(VBANKEXPDATE)', '전문생성일시코드(EDIDATECODE)',
#        '통화구분(CURRENCY)', '승인일자코드(AUTHDATECODE)', '결과코드(RESULTCODE)',
#        '결제순번4(STTLM_SEQ)', '시설대분류코드2(FCLT_LRCLS_CD)',
#        '시설용도구분코드2(FCLT_PRPSE_TPCD)', '시즌구분코드2(SSN_TPCD)', '일자구분코드2(DT_TPCD)',
#        '위약규정일수2(PNLT_RGLTN_DCNT)', '공제율비2(DDCTN_RATE)', '등록일시4(RGTER_ID)',
#        '최종수정일시4(LAST_UPDT_DTM)', '유효여부4(VLDTY_YN)', '부서ID2(DPRTM_ID)',
#        '시설ID(FCLT_ID)', '시설명(FCLT_NM)', '시설설명(FCLT_DSCRT)',
#        '시설대분류코드3(FCLT_LRCLS_CD)', '시설중분류코드(FCLT_MDCLS_CD)',
#        '시설소분류코드(FCLT_SMCLS_CD)', '시설용도구분코드3(FCLT_PRPSE_TPCD)',
#        '시설예약구분코드(FCLT_RSRVT_TPCD)', '시설이미지맵좌표(FCLT_IMAGE_MAP_CRD)',
#        '배치물품내용(PSTNG_THING_CONT)', '구역명(ZONE_NM)', '면적단위(AREA_UNIT)',
#        '면적합계(AREA_SUM)', '최소수용수(MNMM_ACCPT_CNT)', '최대수용수(MXMM_ACCPT_CNT)',
#        '시설오픈일자(FCLT_OPEN_DTM)', '시설폐쇄일자(FCLT_CLSNG_DTM)',
#        '전기시설여부(ELCTY_FCLT_YN)', '난방시설여부(HEAT_FCLT_YN)',
#        '난방시설유형코드(HEAT_FCLT_TPE_CD)', '시설상태코드(FCLT_STCD)', '등록일시5(RGSTN_DTM)',
#        '최종수정일시5(LAST_UPDT_DTM)', '유효여부5(VLDTY_YN)', 'AS-IS 자료(PRODUCT_CODE)',
#        '가로크기(FCLT_SIZE_W)', '세로크기(FCLT_SIZE_H)', '(PPL_CNT)',
#        '법정동코드(LGDNG_CD)', '시도명(CTPRV_NM)', '시군구명(SGNG_NM)', '읍면동명(EMNDN_NM)',
#        '산여부(MNTN_YN)', '시작주번지명(BGN_MIN_LTNMB_NM)', '시작부번지명(BGN_SUB_LTNMB_NM)',
#        '도로코드(ROAD_CD)', '지하여부(UNDRG_YN)', '건물명(BLDNG_NM)',
#        '상세건물명(DTL_BLDNG_NM)', '건물관리명(BLDNG_MNGME_NM)', '읍면동ID(EMNDN_ID)',
#        '행정코드(ADMNS_CD)', '행정코드명(ADMNS_CD_NM)', '우편번호ID(ZIPCD_ID)',
#        '기타명(ETC_NM)', '공동건물여부(CPRTI_BLDNG_YN)', '등록일시6(VLDTY_YN)',
#        '유효여부6(RGSTN_DTM)'],
#       dtype='object')

# %%
import pandas as pd

def reduce_restaurant_payment_data(purchase_df):
    # 1. 음식점 결제 도메인에 매핑할 원본 컬럼과 새 컬럼명 딕셔너리 정의
    # 키(Key): 원본 컬럼명, 값(Value): 변경할 음식점 결제 컬럼명
    rename_mapping = {
        '결제순번(STTLM_SEQ)': 'TID',
        '시설ID(FCLT_ID)': '식당ID', 
        '결제상품금액(AMT)': '총주문금액',
        '결제금액(STTLM_AMT)': '최종결제금액',
        '결제수단(PAYMETHOD)': '결제수단',
        '결제상태코드(STTLM_STCD)': '결제상태코드', 
        '취소금액(CANCELAMT)': '취소금액',
        '부분취소구분(PARTIALCANCELCODE)': '부분취소여부',
        '취소결과코드(CANCELRESULTCODE)': '취소상태',
        '취소사유(CANCELMSG)': '취소사유',
        '등록일시2(RGSTN_DTM)': '최초등록일시',
        '결제완료일시(STTLM_CMPLE_DTM)': '결제완료일시'
    }
    
    available_columns = [col for col in rename_mapping.keys() if col in purchase_df.columns]
    df_core = purchase_df[available_columns].copy()
    df_core = df_core.rename(columns=rename_mapping)
    
    # 4. 결제 관련 텍스트 데이터의 결측치 및 공백 정제
    # 취소 사유 등의 결측치를 빈 문자열로 처리
    fill_dict = {
        '취소금액': 0,
        '총주문금액': 0,
        '최종결제금액': 0,
        '취소사유': '',
        '부분취소여부': 'N',
        '취소상태': '',
        '결제수단': '정보없음'
    }
    # 존재하는 컬럼에 대해서만 결측치 처리
    for col, fill_val in fill_dict.items():
        if col in df_core.columns:
            df_core[col] = df_core[col].fillna(fill_val)
                
    return df_core

# 실행 예시
restaurant_payment_df = reduce_restaurant_payment_data(perchase_df)
restaurant_payment_df.head()
# Out:
#    TID             식당ID    총주문금액   최종결제금액   결제수단 결제상태코드    취소금액 부분취소여부  \
# 0  NaN  F01040300100445   4000.0  58000.0  VBANK   3001     0.0      N
# 1  NaN  F01040300100421   4000.0  10000.0  VBANK   4000  4000.0      Y
# 2  NaN  F01040300100422   4000.0  10000.0  VBANK   3001  4000.0      Y
# 3  NaN  F01040300100448   4000.0  89000.0  VBANK   3001  4000.0      Y
# 4  NaN  F01040300100446  14000.0  10000.0  VBANK   3001  4000.0      Y
#
#      취소상태   취소사유               최초등록일시               결제완료일시
# 0                 2013-05-31 08:48:00  2013-05-31 08:50:00
# 1  2001.0  취소 성공  2013-06-02 22:26:00  2013-06-02 22:33:00
# 2  2001.0  취소 성공  2013-05-20 11:12:00  2013-05-20 11:14:00
# 3  2001.0  취소 성공  2013-05-18 10:58:00  2013-05-18 11:00:00
# 4  2001.0  취소 성공  2013-05-20 10:30:00  2013-05-20 10:32:00

# %%
import pandas as pd
import numpy as np

def build_relational_mock_db(food_df, shop_df, payment_df):
    """
    서로 연관 없는 3개의 데이터셋을 RDB 형태의(상품-상점-결제) 
    """
    # 1. 원본 훼손 방지를 위한 복사
    db_food = food_df.copy()
    db_shop = shop_df.copy()
    db_payment = payment_df.copy()
    
    # 2. 기준키(PK) 목록 추출
    # 식당 PK: 인허가번호 / 음식 PK: 식품코드
    valid_shop_ids = db_shop['인허가번호'].unique()
    valid_food_ids = db_food['식품코드'].unique()
    
    # 3. 결제 테이블(db_payment)에 인위적인 외래키(FK) 덮어쓰기 및 추가
    np.random.seed(42) # 결과 재현성을 위해 난수 시드 고정
    
    # [상점-결제 연결] 기존 식당ID를 무시하고 우리가 가진 식당의 '인허가번호'로 덮어쓰기
    db_payment['식당ID'] = np.random.choice(valid_shop_ids, size=len(db_payment))
    
    # [상품-결제 연결] 어떤 음식을 결제했는지 알 수 있도록 '식품코드' 컬럼 추가 (1결제 = 1상품 가정)
    db_payment['식품코드'] = np.random.choice(valid_food_ids, size=len(db_payment))
    
    # 4. 결제 테이블 컬럼 순서 직관적으로 재배치 (TID, 식당ID, 식품코드 순)
    cols = db_payment.columns.tolist()
    # 식당ID와 식품코드를 맨 앞으로 당겨옴
    cols.insert(1, cols.pop(cols.index('식당ID')))
    cols.insert(2, cols.pop(cols.index('식품코드')))
    db_payment = db_payment[cols]
    
    return db_food, db_shop, db_payment

# ---------------------------------------------------------
# 실행 및 검증 (Verification)
# ---------------------------------------------------------
# 앞서 만든 food_cleaned_df, processed_shop_df, restaurant_payment_df 를 넣고 실행합니다.
final_food_db, final_shop_db, final_payment_db = build_relational_mock_db(
    food_cleaned_df, 
    processed_shop_df, 
    restaurant_payment_df
)

# 1. [상점-결제 연결 검증]
is_shop_linked = final_payment_db['식당ID'].isin(final_shop_db['인허가번호']).all()
print(f"상점-결제 연결 완료 여부: {is_shop_linked}")

# 2. [상품-결제 연결 검증]
is_food_linked = final_payment_db['식품코드'].isin(final_food_db['식품코드']).all()
print(f"상품-결제 연결 완료 여부: {is_food_linked}")
# Out:
# 상점-결제 연결 완료 여부: True
# 상품-결제 연결 완료 여부: True

# %%
restaurant_payment_df.head()
# Out:
#    TID             식당ID    총주문금액   최종결제금액   결제수단 결제상태코드    취소금액 부분취소여부  \
# 0  NaN  F01040300100445   4000.0  58000.0  VBANK   3001     0.0      N
# 1  NaN  F01040300100421   4000.0  10000.0  VBANK   4000  4000.0      Y
# 2  NaN  F01040300100422   4000.0  10000.0  VBANK   3001  4000.0      Y
# 3  NaN  F01040300100448   4000.0  89000.0  VBANK   3001  4000.0      Y
# 4  NaN  F01040300100446  14000.0  10000.0  VBANK   3001  4000.0      Y
#
#      취소상태   취소사유               최초등록일시               결제완료일시
# 0                 2013-05-31 08:48:00  2013-05-31 08:50:00
# 1  2001.0  취소 성공  2013-06-02 22:26:00  2013-06-02 22:33:00
# 2  2001.0  취소 성공  2013-05-20 11:12:00  2013-05-20 11:14:00
# 3  2001.0  취소 성공  2013-05-18 10:58:00  2013-05-18 11:00:00
# 4  2001.0  취소 성공  2013-05-20 10:30:00  2013-05-20 10:32:00

# %%
final_payment_db.head()
# Out:
#    TID         식당ID                 식품코드    총주문금액   최종결제금액   결제수단 결제상태코드  \
# 0  NaN  19940076691  D202-120000000-1960   4000.0  58000.0  VBANK   3001
# 1  NaN  20040077626  D220-737000000-1310   4000.0  10000.0  VBANK   4000
# 2  NaN  20000076189  D202-120000000-2146   4000.0  10000.0  VBANK   3001
# 3  NaN  19940076326  D220-748000000-0531   4000.0  89000.0  VBANK   3001
# 4  NaN  19920076417  D301-031000000-0001  14000.0  10000.0  VBANK   3001
#
#      취소금액 부분취소여부    취소상태   취소사유               최초등록일시               결제완료일시
# 0     0.0      N                 2013-05-31 08:48:00  2013-05-31 08:50:00
# 1  4000.0      Y  2001.0  취소 성공  2013-06-02 22:26:00  2013-06-02 22:33:00
# 2  4000.0      Y  2001.0  취소 성공  2013-05-20 11:12:00  2013-05-20 11:14:00
# 3  4000.0      Y  2001.0  취소 성공  2013-05-18 10:58:00  2013-05-18 11:00:00
# 4  4000.0      Y  2001.0  취소 성공  2013-05-20 10:30:00  2013-05-20 10:32:00

# %%
import pandas as pd
import re

def translate_columns_to_english(food_db, shop_db, payment_db):
    # 1. 영문 매핑 딕셔너리 정의
    food_rename_dict = {
        '식품코드': 'food_id', '업체명': 'company_name', '식품명': 'food_name', 
        '대표식품명': 'rep_food_name', '식품대분류명': 'major_category', 
        '식품중분류명': 'sub_category', '기준량(g)': 'serving_size_g', 
        '에너지(kcal)': 'energy_kcal', '단백질(g)': 'protein_g', '지방(g)': 'fat_g', 
        '탄수화물(g)': 'carbs_g', '당류(g)': 'sugar_g', '식이섬유(g)': 'dietary_fiber_g', 
        '나트륨(mg)': 'sodium_mg', '칼륨(mg)': 'potassium_mg', '콜레스테롤(mg)': 'cholesterol_mg', 
        '포화지방산(g)': 'sat_fat_g', '트랜스지방산(g)': 'trans_fat_g', '데이터기준일자': 'data_ref_date', 
        '에너지밀도(kcal/g)': 'energy_density_kcal_g', '탄수화물_에너지비율(%)': 'carbs_energy_ratio_pct', 
        '단백질_에너지비율(%)': 'protein_energy_ratio_pct', '지방_에너지비율(%)': 'fat_energy_ratio_pct', 
        '단백질_INQ': 'protein_inq', '당류비율(%)': 'sugar_ratio_pct', '나트륨_칼륨_비율': 'na_k_ratio'
    }
    
    shop_rename_dict = {
        '인허가번호': 'shop_id', '업소명': 'shop_name', '영업상태코드': 'biz_status_code', 
        '도로명주소': 'road_address', '소재지주소': 'land_address', 
        '전화번호': 'phone_number', '음식의유형': 'food_type', '주된음식종류': 'main_dish_type'
    }
    
    payment_rename_dict = {
        'TID': 'tid', '식당ID': 'shop_id', '식품코드': 'food_id', 
        '총주문금액': 'total_order_amt', '최종결제금액': 'final_pay_amt', 
        '결제수단': 'pay_method', '결제상태코드': 'pay_status_code', 
        '취소금액': 'cancel_amt', '부분취소여부': 'is_partial_cancel', 
        '취소상태': 'cancel_status', '취소사유': 'cancel_reason', 
        '최초등록일시': 'created_at', '결제완료일시': 'paid_at'
    }
    
    # 2. 컬럼명 변경 적용 (원본 보호를 위해 copy)
    en_food_db = food_db.copy().rename(columns=food_rename_dict)
    en_shop_db = shop_db.copy().rename(columns=shop_rename_dict)
    en_payment_db = payment_db.copy().rename(columns=payment_rename_dict)
    
    return en_food_db, en_shop_db, en_payment_db

# ---------------------------------------------------------
# 실행 및 검증 (Verification)
# ---------------------------------------------------------
# 함수 실행
en_food_db, en_shop_db, en_payment_db = translate_columns_to_english(
    final_food_db, 
    final_shop_db, 
    final_payment_db
)

# [컬럼명 영어 변환 검증] 정규표현식(영문자, 숫자, 언더스코어로만 구성) 사용
def verify_english_columns(df, db_name):
    pattern = re.compile(r'^[a-zA-Z0-9_]+$')
    all_english = all(pattern.match(col) for col in df.columns)
    print(f"{db_name} 영문 컬럼명 변환 완료 여부: {all_english}")

verify_english_columns(en_food_db, "상품(Food) 테이블")
verify_english_columns(en_shop_db, "상점(Shop) 테이블")
verify_english_columns(en_payment_db, "결제(Payment) 테이블")

# 최종 결과 확인
en_payment_db.head()
# Out:
# 상품(Food) 테이블 영문 컬럼명 변환 완료 여부: True
# 상점(Shop) 테이블 영문 컬럼명 변환 완료 여부: True
# 결제(Payment) 테이블 영문 컬럼명 변환 완료 여부: True
#    tid      shop_id              food_id  total_order_amt  final_pay_amt  \
# 0  NaN  19940076691  D202-120000000-1960           4000.0        58000.0
# 1  NaN  20040077626  D220-737000000-1310           4000.0        10000.0
# 2  NaN  20000076189  D202-120000000-2146           4000.0        10000.0
# 3  NaN  19940076326  D220-748000000-0531           4000.0        89000.0
# 4  NaN  19920076417  D301-031000000-0001          14000.0        10000.0
#
#   pay_method pay_status_code  cancel_amt is_partial_cancel cancel_status  \
# 0      VBANK            3001         0.0                 N
# 1      VBANK            4000      4000.0                 Y        2001.0
# 2      VBANK            3001      4000.0                 Y        2001.0
# 3      VBANK            3001      4000.0                 Y        2001.0
# 4      VBANK            3001      4000.0                 Y        2001.0
#
#   cancel_reason           created_at              paid_at
# 0                2013-05-31 08:48:00  2013-05-31 08:50:00
# 1         취소 성공  2013-06-02 22:26:00  2013-06-02 22:33:00
# 2         취소 성공  2013-05-20 11:12:00  2013-05-20 11:14:00
# 3         취소 성공  2013-05-18 10:58:00  2013-05-18 11:00:00
# 4         취소 성공  2013-05-20 10:30:00  2013-05-20 10:32:00

# %%
en_food_db.head()
# Out:
#                food_id company_name food_name rep_food_name major_category  \
# 0  D101-004160000-0001         해당없음   국밥_돼지머리            국밥             밥류
# 1  D101-004310000-0001         해당없음   국밥_순대국밥            국밥             밥류
# 2  D101-004500000-0001         해당없음    국밥_콩나물            국밥             밥류
# 3  D101-006000000-0001         해당없음       기장밥           기장밥             밥류
# 4  D101-007000000-0001         해당없음        김밥            김밥             밥류
#
#   sub_category  serving_size_g  energy_kcal  protein_g  fat_g  carbs_g  \
# 0         돼지머리             100          137       6.70   5.16    15.94
# 1         순대국밥             100           75       3.17   2.28    10.38
# 2          콩나물             100           52       1.45   0.24    10.93
# 3         해당없음             100          166       3.44   0.57    36.77
# 4         해당없음             100          140       4.84   4.55    19.98
#
#    sugar_g  dietary_fiber_g  sodium_mg  potassium_mg  cholesterol_mg  \
# 0     0.16              0.7      181.0          47.0           23.82
# 1     0.17              1.3      126.0          34.0           48.69
# 2     0.00              1.2      172.0          42.0            0.00
# 3     0.00              1.5        1.0          25.0            0.00
# 4     0.00              1.4      307.0         118.0           19.30
#
#    sat_fat_g  trans_fat_g data_ref_date  energy_density_kcal_g  \
# 0       1.47         0.03    2025-12-29                   1.37
# 1       1.26         0.01    2025-12-29                   0.75
# 2       0.12         0.00    2025-12-29                   0.52
# 3       0.08         0.00    2025-12-29                   1.66
# 4       1.10         0.02    2025-12-29                   1.40
#
#    carbs_energy_ratio_pct  protein_energy_ratio_pct  fat_energy_ratio_pct  \
# 0                   46.54                     19.56                 33.90
# 1                   55.36                     16.91                 27.36
# 2                   84.08                     11.15                  4.15
# 3                   88.60                      8.29                  3.09
# 4                   57.09                     13.83                 29.25
#
#    protein_inq  sugar_ratio_pct  na_k_ratio
# 0         1.78             1.00        3.85
# 1         1.54             1.64        3.71
# 2         1.01             0.00        4.10
# 3         0.75             0.00        0.04
# 4         1.26             0.00        2.60

# %%
import os
import pandas as pd
import time
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# ---------------------------------------------------------
# 0. 환경 변수 및 사전 데이터 준비
# ---------------------------------------------------------
print("1. 데이터 프레임 병합 및 RAG용 자연어 컨텍스트 생성 시작...")

# 1. 업체명이 있는 데이터만 필터링하여 RAG 도큐먼트 생성에 활용 (업체명 없는 데이터는 RAG 컨텍스트로 활용하기 어려움)
company_food_db = en_food_db[en_food_db['company_name'] != '해당없음']
sampled_df = company_food_db.copy()

# 2. [page_content 정적 데이터 최적화 & 메타데이터 분리]
def build_general_rag_documents(df):
    docs = []
    for _, row in df.iterrows():
        page_content = f"""
브랜드: {row['company_name']}
메뉴 특징: {row['major_category']} 분류에 속하는 {row['food_name']} 메뉴입니다.
영양 및 열량: 1회 제공량 {row['serving_size_g']}g 기준으로 {row['energy_kcal']}kcal의 에너지를 냅니다.
주요 성분: 단백질 {row['protein_g']}g, 탄수화물 {row['carbs_g']}g, 지방 {row['fat_g']}g이 포함되어 균형 잡힌 식사가 가능합니다.
""".strip()
        metadata = {
            "food_id": str(row['food_id']),
            "company_name": str(row['company_name']),
            "food_name": str(row['food_name']),
            "protein_inq": float(row['protein_inq']),
            "na_k_ratio": float(row['na_k_ratio'])   
        }
        
        docs.append(Document(page_content=page_content, metadata=metadata))
    return docs

# 문서 변환 실행
documents = build_general_rag_documents(sampled_df)
print(f"-> 총 {len(documents)}개의 범용 RAG 도큐먼트 변환 완료 (업체명 있는 데이터 적용).")

# 3. 임베딩 및 Chroma DB 구축
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

DB_PATH = "./food_db"

# [수정된 부분] 한 번에 적재하던 from_documents를 제거하고, 빈 DB 생성 후 분할 적재
db = Chroma(
    embedding_function=embeddings,
    persist_directory=DB_PATH,
    collection_metadata={"hnsw:space": "cosine"},
    collection_name="food_db_V1" 
)

print("-> Vector DB 분할 적재 시작 (TPM 제한 방지)...")
batch_size = 300  # 한 번에 처리할 도큐먼트 개수 (한도 초과 시 이 숫자를 줄이세요)

for i in range(0, len(documents), batch_size):
    batch_docs = documents[i : i + batch_size]
    db.add_documents(batch_docs)
    print(f"   - {min(i + batch_size, len(documents))} / {len(documents)} 개 적재 완료. (잠시 대기 중...)")
    time.sleep(2)  # 2초 대기하여 1분당 토큰 발생량을 분산

print("-> Vector DB 전체 적재 완료.\n")

# ---------------------------------------------------------
# [추가됨] 과제 제출용 정량적 검증 (Quantitative Verification)
# ---------------------------------------------------------
print("="*50)
print(" [정량적 검증] Vector DB 구축 결과 확인")
print("="*50)

# 1) 임베딩 차원(Dimension) 검증
sample_embed = embeddings.embed_query("테스트")
model_dim = len(sample_embed)

db_sample = db._collection.get(limit=1, include=['embeddings'])

if db_sample.get('embeddings') is not None and len(db_sample['embeddings']) > 0:
    db_dim = len(db_sample['embeddings'][0])
else:
    db_dim = 0

print(f"▶ 임베딩 모델({embeddings.model}) 기본 차원 수: {model_dim}")
print(f"▶ Vector DB 적재 차원 수: {db_dim}")
print(f"☞ 차원 일치 여부: {'일치 (PASS)' if model_dim == db_dim else '불일치 (FAIL)'}")
print("-" * 50)

# 2) 데이터 개수(Count) 검증
total_chunks = len(documents)
db_count = db._collection.count()

print(f"▶ 텍스트 스플리터/생성된 총 청크 수: {total_chunks}개")
print(f"▶ Vector DB 최종 적재 도큐먼트 수: {db_count}개")
print(f"☞ 개수 일치 여부: {'일치 (PASS)' if total_chunks == db_count else '불일치 (FAIL)'}")
print("="*50 + "\n")

# ---------------------------------------------------------
# 4. 범용 유사도 검색 테스트 (Qualitative Verification)
# ---------------------------------------------------------
print("="*50)
print(" [정성적 검증] 유사도 검색(Similarity Search) 테스트")
print("="*50)

test_query = "투썸플레이스에 커피음료 추천해줘"
print(f"Q: '{test_query}'\n")

# k=3 개 추출하여 점수 확인
results = db.similarity_search_with_score(test_query, k=3)

for i, (doc, distance) in enumerate(results, 1):
    # 코사인 거리(Cosine Distance)를 코사인 유사도(Cosine Similarity)로 변환
    similarity = 1 - distance
    
    print(f"[{i}순위] 메뉴: {doc.metadata['company_name']} - {doc.metadata['food_name']}")
    print(f"  - 유사도 점수: {similarity:.4f} " + ("(적합👍)" if similarity >= 0.7 else "(다소 낮음)"))
    print("-" * 40)
# Out:
# 1. 데이터 프레임 병합 및 RAG용 자연어 컨텍스트 생성 시작...
# -> 총 15351개의 범용 RAG 도큐먼트 변환 완료 (업체명 있는 데이터 적용).
# -> Vector DB 분할 적재 시작 (TPM 제한 방지)...
#    - 300 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 600 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 900 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 1200 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 1500 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 1800 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 2100 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 2400 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 2700 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 3000 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 3300 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 3600 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 3900 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 4200 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 4500 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 4800 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 5100 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 5400 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 5700 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 6000 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 6300 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 6600 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 6900 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 7200 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 7500 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 7800 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 8100 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 8400 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 8700 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 9000 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 9300 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 9600 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 9900 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 10200 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 10500 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 10800 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 11100 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 11400 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 11700 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 12000 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 12300 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 12600 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 12900 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 13200 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 13500 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 13800 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 14100 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 14400 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 14700 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 15000 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 15300 / 15351 개 적재 완료. (잠시 대기 중...)
#    - 15351 / 15351 개 적재 완료. (잠시 대기 중...)
# -> Vector DB 전체 적재 완료.
#
# ==================================================
#  [정량적 검증] Vector DB 구축 결과 확인
# ==================================================
# ▶ 임베딩 모델(text-embedding-3-small) 기본 차원 수: 1536
# ▶ Vector DB 적재 차원 수: 1536
# ☞ 차원 일치 여부: 일치 (PASS)
# --------------------------------------------------
# ▶ 텍스트 스플리터/생성된 총 청크 수: 15351개
# ▶ Vector DB 최종 적재 도큐먼트 수: 26573개
# ☞ 개수 일치 여부: 불일치 (FAIL)
# ==================================================
#
# ==================================================
#  [정성적 검증] 유사도 검색(Similarity Search) 테스트
# ==================================================
# Q: '투썸플레이스에 커피음료 추천해줘'
#
# [1순위] 메뉴: 투썸플레이스 - 커피_카페모카 아이스(ICED) (R)
#   - 유사도 점수: 0.5518 (다소 낮음)
# ----------------------------------------
# [2순위] 메뉴: 투썸플레이스 - 커피_아메리카노 아이스(ICED) (R)
#   - 유사도 점수: 0.5505 (다소 낮음)
# ----------------------------------------
# [3순위] 메뉴: 투썸플레이스 - 커피_아메리카노 아이스(ICED) (L)
#   - 유사도 점수: 0.5464 (다소 낮음)
# ----------------------------------------

# %%
import os
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# 1. 저장할 때 사용한 것과 동일한 임베딩 모델 초기화
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

DB_PATH = "./food_db"

# 2. [Vector DB 로드] 기존 경로와 컬렉션 이름으로 연결
db = Chroma(
    persist_directory=DB_PATH,
    embedding_function=embeddings,
    collection_name="food_db_V1"
)

# 3. [검증] 데이터가 정상적으로 불러와졌는지 개수 확인
db_count = db._collection.count()
print(f"✅ 불러오기 완료: 총 {db_count}개의 도큐먼트가 로드되었습니다.")

db.get()
# Out:
# ✅ 불러오기 완료: 총 26573개의 도큐먼트가 로드되었습니다.
# {'ids': ['32fd199e-abdd-4fd0-aa8b-b60d97500188',
#   'c94968ce-5764-4a5d-a876-b09220408f6b',
#   '6d13d064-b27e-42de-bcdb-14f6e4215450',
#   'ebdf9fe3-f39e-4930-876c-4d1eda69c7d1',
#   '9cd0ab86-ed3b-4db3-8c53-0e40d6be1052',
#   '160f1a7e-83fe-427f-9f41-fa3e823a79a7',
#   'c960ae85-0770-4fe6-a332-cd31e1e56310',
#   'fb1de0cf-b021-4fe1-8eba-dd7606820786',
#   'e8baa7e1-37a7-41a5-ab56-bc5f8531fa3b',
#   '45cec651-b770-4be9-a9b6-227b9792d6bb',
#   '8889de2b-0a48-4bd7-96c3-1875d356dfd9',
#   'd45c063f-6de5-431e-bb55-410b89178781',
#   '198565e7-60a2-435f-a4e7-22823c151199',
#   '2cb5ac79-5888-4c04-ab46-5ea1f8949e5e',
#   '59437f45-6f09-42c7-bb30-003cf661435e',
#   'cf89e7ff-bba5-4650-bf65-7f5c403651d3',
#   'afcff85c-57c1-489a-bf2a-059f4e7d5a62',
#   '18a34034-fef9-48c6-b43f-4855a0dd787f',
#   '89405110-109a-4a48-adef-1534b4581731',
#   '7dbb5766-9efd-441b-b55b-f8f16f5633fe',
#   'b637d061-c230-4c9b-b07b-c346e74af219',
#   '4c6e67bc-754c-4214-9e67-6fb004be405e',
#   '55fd49e3-cd1d-4f30-bc05-6a3b88fda2a8',
#   'd4c73296-b699-4910-a4e5-adbabac59390',
#   '61b76e5e-a0ea-4dc3-897e-6672ea3d4464',
#   '8e7536db-9fb3-400f-8e88-7dd68f6217e7',
#   '3e48b8ac-e090-40e6-a2ce-2a27a6abf547',
#   '6ea9f03b-b8fa-44ad-8361-31cec132fa4e',
#   '24dd96a5-2a42-4d9c-955b-e4c580260d17',
#   '73092622-4dd1-4fc9-b97e-28007f0c2238',
#   '8e4008eb-c13d-4e09-bcfc-dfdbcd43a3a8',
#   'fdf2f864-0235-47de-8e9f-c64a50daa876',
#   'a953db41-88c7-4fd8-b096-10c782078fb2',
#   'b61b41a9-c6e3-454f-974e-55f211616b40',
#   '9a0420b9-84e4-49db-b4bb-66b7c21fc381',
#   '3dbaa7a6-35ec-44ec-8555-82e4153a1e32',
#   '82007b5f-7cb1-4cb5-af24-20702e189021',
#   'ca4480cd-2447-4115-b995-67950522e301',
#   'b40c5e98-da7b-4e02-b98c-b56b13a649fd',
#   'e29b6b55-b841-464d-b166-12547ab792b4',
#   'cd5317c2-7628-4953-8c93-979cc692b3dc',
#   '54589a7e-810b-4fcc-b10a-8e00ad3f6b27',
#   '779208e5-d1f3-4971-899b-074328a8cc97',
#   'b6f9372e-47ae-46c6-aaf1-03606105ee51',
#   '891b2255-9b54-42be-9011-b088dded9910',
#   '26903f44-cc5e-4e90-b302-dac409d1bb89',
#   '9323e7fd-951e-4695-8ef2-d27fddbb71c4',
#   'ed34b43b-6dbd-45a3-af53-3ecd7ee52271',
#   'be2f5655-af10-4863-bb64-50afddd9e2d8',
#   '3302d581-d989-4fb2-bdaf-af599db5e812',
#   'b6207727-767a-4913-8c41-e512144a2e33',
#   'd3a2fb81-2af4-41d8-a779-27096b07776a',
#   '1bc2b0e2-7cf1-48fd-8eca-b1ae73a07073',
#   '39675ff5-750a-4ced-bab2-5667ed92ef1a',
#   '98a58e2d-4ba3-4025-80ee-95e4f49c252a',
#   'fc9422f4-70fc-445f-ad14-d92797ddbe30',
#   '657054cf-d9f1-4d28-bdef-8b5747c3d514',
#   'a7390f91-3659-4f5f-9988-f601eca37ace',
#   '6ab117f1-af7d-4f60-a4b2-89b6523831f1',
#   '88b8ad71-bc22-49bb-920d-05e423ef7d2c',
#   '8e12fbde-820f-4c23-bacd-66a64ff54945',
#   'b8a4627c-25aa-4363-b4ab-c33b00085585',
#   'cce07df2-33c7-4720-9b88-9e56b642871c',
#   '9cc6a2c1-305a-4480-9d6f-d0bcfc53b8f0',
#   '80ba8407-9de1-4685-8a5a-9b7e3ac25097',
#   'ccbac7a1-d576-4b9e-872c-408070595527',
#   '91a194e0-eb15-4232-a570-e843359c92ae',
#   '9f3b7ba9-0abd-43be-a45e-f78e39507562',
#   'adc29ca6-78d9-4c2f-94f7-4a83553619e8',
#   '23abf29d-4bde-4448-94d0-ab5cdc2ee1b1',
#   '863ea1e8-7651-4852-ae4d-f719a9a8e421',
#   '980385e1-b9f0-481c-acb0-55c08b7956b5',
#   '61d96529-dcfd-41ed-916e-e01ad1c49f64',
#   '73927fe0-482f-4e6d-b04a-a8b2b9b9b2c7',
#   'bd7edc4e-abbe-4e85-b9f2-c427c36a6ee6',
#   '4efd8467-5967-48c6-bacd-21f9ecc0440e',
#   '57ecdfd7-b28f-4ca3-8afa-86f59471c414',
#   'f4f1a3a6-5b0e-485c-8ea4-525753688c2c',
#   '6f33f241-f79a-4329-b79a-7c5416517806',
#   'dfe6092e-d5c9-4c7d-944a-2d7376e50e8f',
#   'ce9ae33c-a0b9-44f1-b02b-9c8f601e060a',
#   '3bcaa5bc-2017-4269-aa3a-908fb81aae1a',
#   '5d07c519-18fb-4c94-a221-76c90d27d147',
#   '798545a8-d837-4942-9d0e-aa5db0c9d412',
#   '7dfc4cfb-f835-4ca8-af25-488d59ec12d5',
#   'ca6a9684-13c7-466e-8cd8-c01062f9c61c',
#   '87b85919-6fb5-4f86-a0cd-5bb7e569691d',
#   '4c6d4c54-db60-493c-9ea3-82f8ae58d135',
#   '047be716-f10b-4151-b7fe-3c6c74748edc',
#   '0461165a-b386-4016-931a-93e8cb081cef',
#   'f865ee1f-b0c3-44f6-8bcb-c7d29a5b2d00',
#   '6513f973-cf54-46fe-9daa-3525be01de05',
#   '21fc49d8-9ca4-4835-89ae-81b68d03af64',
#   'c474e590-14fb-4195-906a-fb1f73ddb512',
#   '9debe24c-04a6-4a96-b112-5fcbf575fa28',
#   '56e0de16-e102-4971-8684-2e61b178c00f',
#   '343f43d3-b5cc-4c84-9ff4-3773b34e372b',
#   '7345fe52-9ece-4159-8ce8-753ab5de57c2',
#   '963e18e2-63b8-47e0-a88e-28332fc7d828',
#   '4b552720-0e48-453e-8e72-3dc8aa2bc00f',
#   '5f290fd0-056c-4293-8219-38717d0e0e1e',
#   '72049bea-b7a0-41bd-93fe-aa46087968e0',
#   '4a16efd3-b154-476b-b5cb-b38abf949bdc',
#   'fa5235de-b886-4140-86e5-80e00c85bee0',
#   'c2840f08-52e8-467f-a766-d1fe8ee0b1e6',
#   'd428f259-d7e4-414b-987d-4cfd9fdee281',
#   '6c004449-e707-44ae-b357-055b40953a09',
#   'e4d04d88-d474-456a-b0f9-6b68e3cc1874',
#   'e0d29128-d575-48bb-8797-2248b0a9c414',
#   '4d25b1f3-5ce9-40b8-aab0-9eac4c7f4455',
#   '30bcbb81-2f44-4d45-b690-29e439afe267',
#   'f1cfc691-8bc5-45cc-a5b3-71e760ba67a5',
#   '51d239a5-c926-431c-a0c8-53ba1445a746',
#   '6a1a0cca-5ec2-41c7-98ff-d8ef585f79d5',
#   '1eeacbf0-43e3-4e25-bdb0-d7803eefebef',
#   '001df2cf-6263-4b80-bb88-64b3083b8489',
#   '4c7bb1fa-65d8-4143-877c-14b91bd9158a',
#   '505ee533-ecc4-4678-a831-91f56633ba28',
#   '333554a8-7a33-4b47-91e7-6ee3508ac9b8',
#   '3feda75e-b638-48b7-b45c-556a2788ae10',
#   '89730c66-2b44-48c2-9719-9b6bf2758c8f',
#   'f4c9775f-9aaa-4e0e-bc72-4e9fdcee0c10',
#   '806c7726-1bc1-4feb-999b-27bfd485495b',
#   '93aa134c-a2ee-41db-a087-820c4d7f8115',
#   '765d8dd0-b376-4352-8af1-b7c09aa12c45',
#   '46af7ff1-b340-4279-a802-0078b865961d',
#   'b20d0d46-8f0d-48f9-8b65-0694fe2f659f',
#   'c8b415d7-69d7-424c-8d2e-cfcef80be37e',
#   '32b7f648-1201-4774-a264-719d441a4f8f',
#   'd2245219-1264-4237-9066-025ccd365429',
#   '50c42a25-53b5-4b22-b183-101a298a2827',
#   'd0d38ff1-6937-4c05-a935-6a4e801a20ec',
#   '29dd2019-396e-4bac-b4fb-7fd58c7c07fd',
#   'a0bf5bfc-b405-4333-9f87-c64bf3a06938',
#   '4c5c0608-b1d9-45e0-829a-9800d8026b58',
#   '7c6fbd3d-6ee1-428d-9203-8b893c70f5ac',
#   '6d285cb5-6f5b-4222-bad7-675270f75af7',
#   '828218a7-136e-4212-8eba-c281e49308b6',
#   '9a7a9555-0a41-495c-bb62-bb0149e8f48e',
#   '9612199c-e224-4282-889a-92ded0ce4b63',
#   '2e872010-b124-4c35-a6d2-d1db3b7bef1c',
#   'd6d6e480-4c6b-45c6-83e5-5c9be3c57fb5',
#   '4697fd96-3b35-4318-9ff9-27ebc632e4ae',
#   '05949056-48d5-4cb8-a98b-3a1ded5cfc28',
#   'a819a7b1-6efe-458e-bd69-865f00f1e3d7',
#   '5d8aee52-03d2-471c-b682-7619f2ec022c',
#   '52cf92b5-09e7-4b02-ad5b-d30b3271f97d',
#   '5996f477-7dd5-4081-b0cb-ec272d59b813',
#   '9ecad851-1b3a-4448-8c72-edab2724cf90',
#   '44a6a905-e75a-4ed0-b0c8-580df403a828',
#   '777daaae-cf60-4efe-b283-6f60d2420080',
#   '5f8ab34a-deae-443b-9995-d5dd8967040a',
#   '9d05f9d2-e300-45d1-a68d-6e1139bb5458',
#   '1553750f-ea25-4294-9949-a4a9e580cb52',
#   'a1a3ba20-bf28-4d37-8972-6b815567fbec',
#   'dc60e254-a7c5-4bba-bc78-57c714cc1b16',
#   '70530626-5e97-468a-b2a0-ea7f388c5f65',
#   '9a641633-a8cd-47c1-976d-50bf83b5b2d9',
#   '0c20be6a-0716-48a4-bab6-37872f90481a',
#   'e662fd59-5854-44fa-a5e8-fd69cacbd923',
#   'e6f62694-323c-48e2-bc48-87054bf5fbe4',
#   'bf9e67d7-3be9-4a6b-ba37-7030d65e4e77',
#   '0978f7ab-73d6-4275-88b5-5a768d46a442',
#   '699d3270-c944-45c0-8ea2-a0c1463ae773',
#   'd11cda7f-c48b-46b3-a3f0-c1dee33a5278',
#   '350e0e65-456d-4d3e-a8f6-16d3d173e28a',
#   '3b116431-b0bf-4a2d-a14b-8abd36fa7697',
#   'd0c7ab82-038f-4c5a-8ac9-66c2b8f83f42',
#   '6d933680-93db-4663-b2cc-754c7264a439',
#   '0cb9ccc7-d4ae-41fd-aabe-c31c2d7ce8fb',
#   '83588a9c-b28e-4ab8-9a82-e9991ad9e833',
#   '1bf41912-96fd-4c49-84f9-2f1f67c66b00',
#   'ca6f0041-c6d3-44e4-9a0c-e95e9e148337',
#   '1a155c7d-93a2-43bb-a641-34d895193244',
#   '7b89c1eb-3082-450d-9554-4cdeefc9bc02',
#   'ed206c18-5b2f-47bf-8065-2310153d161c',
#   '57d421e6-3a1d-483c-adad-834a7556a468',
#   '6f59ee1b-7331-46d6-9b30-63f977fd4f45',
#   '2b3771fd-c57d-4079-90ce-5b4d1eeebe7a',
#   '5b86b71f-284a-4be4-9b64-dc790a3eafee',
#   '7d6df445-1109-4fca-8880-da72f3153299',
#   '867ef1ae-64c1-4ec1-a3f5-db370b532b46',
#   '69fa4300-dd5a-4ebb-be32-e9d384f5c4ac',
#   '046a5698-09da-4478-8a06-1e084179514b',
#   'a884f163-61fe-49f1-ac04-31bb403958d1',
#   '8489eed9-6f5b-4219-9d31-d08071f7b182',
#   '27b1c33a-004e-4a28-8bcc-f2ff09d86c53',
#   '63074f4f-9090-4201-a2db-fb7dc5c9e283',
#   'df4b1a0f-09ce-4afb-9e69-6bbd1bf40b45',
#   '02247ec3-20e1-40ed-9bfd-6e35abdf414f',
#   'c63f71ba-7740-4d55-8f59-4ece6558564f',
#   '33719cb5-7690-4299-8cf9-ef3854a518a2',
#   '354b687f-e70a-4a2d-a424-85dbda8d2e8f',
#   'b156f8cb-319d-4b9e-b522-edfe2dc75cf4',
#   '526ec7b0-c050-4cd1-aa6b-80847eba9043',
#   'a022c281-a1a2-44a6-851b-394277e2e8d9',
#   'bb1238d7-47ed-45b5-b805-dddef404ccc4',
#   'd2f4009e-de63-4fd9-a17d-fe2952076a26',
#   'cc32686c-0625-440b-a96c-ff06d99f573e',
#   'e84fefeb-4901-483d-992f-b69912782349',
#   '28a654c5-13f3-4ca7-be3a-b311a546463c',
#   '7c669867-032c-4998-b336-1a5dc8a46c88',
#   'f7fccc01-dac3-4a4e-9b1f-f3276e92b601',
#   '53a85caf-9fc6-4c05-bcca-4e159a0cb55e',
#   'e5534677-70c4-4143-be4f-3915d320b4b1',
#   '7240503e-71c7-4cae-a7c8-fc701b3b5432',
#   '2f5cf1d3-cf5c-4697-b5e2-2647f46395b1',
#   'd904bb7a-e815-4f2b-8dcc-78e00da84b29',
#   '9046c6ec-bb29-480d-8b99-9515c9afd5c7',
#   'd1e313c9-73ef-45a2-95dc-491298270367',
#   'b162c08a-4a80-493d-b8e1-ffa362a41722',
#   'f8eaa872-2fe1-4d52-a143-4922fbc1299d',
#   '9a9fe601-5e54-45ba-8658-8591ebb13067',
#   'fcbec172-a2b9-48ae-bd52-519ac7c7daa8',
#   '30b9cd6e-7017-43b0-8ff6-3ce45b6d08dd',
#   'be2c8961-76ba-4572-852c-b74913bee451',
#   'e94cc9f2-f6d6-4d72-9b60-5c4984cee989',
#   'c090c7bb-90ba-454c-97c0-cec915bfb3d8',
#   '64dea1b9-19c3-41d1-bf97-b683925272fd',
#   '855184c2-2c68-49f6-8e80-57248d3223cb',
#   '89b69e82-9915-4e38-944f-4dfc146a3dbe',
#   'fd2aa7cb-8bef-42eb-86c6-c898a6ea6afc',
#   '0d296cec-379c-44d0-b8f5-4745e9609691',
#   '9f38c799-7fac-408f-9518-9a7220607cbf',
#   'c5619ea4-7d12-474f-a41c-44e7a849f05f',
#   '76b04621-066a-43cc-b4c6-6c568d5ac8c5',
#   '7240ee94-6e6d-41ee-8e3e-bfd3a8f08190',
#   '6c93aca1-a9a7-43a1-9b73-78ab74995610',
#   '553b4cc1-ffec-4b92-b9c3-74d287c106e3',
#   '6d91d66d-6fb0-46ee-818c-14da3fd33dab',
#   'aaa207d9-4834-4546-9671-7093032d1450',
#   'dd8f56dc-732a-4981-9600-def5e288f02e',
#   '996aae29-886e-4a83-a62f-41aa7dc8f827',
#   'fe814cdf-1796-4c9c-b62e-26605fcf56e7',
#   '30c8ff0b-62fc-4a99-a33c-2801711e470c',
#   'ab78b019-6d51-4b8f-9ba8-208abc5c0b5d',
#   '4050254b-a827-4ac5-87a3-cc176601df38',
#   '9874fa31-a653-47f9-80f8-0439c4292774',
#   '45f83f87-6638-4ea4-8c9a-8c897975906f',
#   '363a5250-dd15-4a31-a8e9-5df3a912653a',
#   '49360f4e-9371-4902-8a25-8708c4227fa6',
#   '0bc8d203-8a23-4741-8ba7-e926e59cf05c',
#   '7a4251ef-041a-457c-ac6e-f563450abbbd',
#   '3fea9cdf-abec-470c-9dc7-c315ed8af741',
#   'fa7fccd8-e9dc-4524-bc2b-eaf7c1e67ac3',
#   '6fa59141-17a3-40b3-88f9-1f7ec75f9355',
#   '45ff2288-ffd5-4779-952b-c0ef7c30e0be',
#   'f72727ad-1706-42ab-b94d-de388b0c8f6b',
#   '653fc31b-f5f4-4d6e-97d9-c26ac219c70e',
#   'ceb90874-914b-4699-820c-dedec52c5fe8',
#   'a542b184-e02a-464d-9a88-6d63570e8a07',
#   '3f83fa84-4b95-40ed-af33-4089b4574f31',
#   '33a9e469-ea16-4f19-b926-58fd08a6fb52',
#   '2c243c05-fd04-4c6d-933f-1f20def733d9',
#   'f4cd888b-978b-4407-8824-c7df0bed5ba3',
#   '70c753fe-89e8-4087-9f2e-5bf655a67988',
#   'dfed4615-e588-4473-867f-dd58d79ab9b2',
#   '09e7d35b-6458-47e9-b74c-e67043a35393',
#   'fa745b86-f979-4fe2-98a4-84c18df2dfe8',
#   '44a8db0e-7207-4d55-81d1-e08bdf407b1d',
#   'ecc16e3c-a051-45d7-bc41-8c4284739c8f',
#   'e4a0c541-adb8-42d4-a536-1bbf80e8c624',
#   'b41b325b-fe7d-45b7-9926-1a318af1d722',
#   '9c4ac54d-563c-4c69-ae37-c2e5fda2d6af',
#   '38f2baec-5536-4958-b961-e0a5ee7a058f',
#   '1aba0dc2-45e7-46f4-af83-8a08b9babc4c',
#   '3221fbbf-b4bf-496f-a55c-730f9fc59250',
#   'f28223ed-45de-47e5-acfe-3bc2c53c3d55',
#   'c28324e6-a1dc-4f01-b5d2-09d8411eb034',
#   '859811d3-0103-45e0-8708-989dba5b6795',
#   'bba3fe2f-0346-48b0-b716-28f18d38276a',
#   '18d9e71f-c368-43f2-a450-1703290c9d16',
#   '4e6ffbc1-5e8d-4e23-bec5-ec4cf2c8755b',
#   '205d7890-a86d-479a-8d19-8d4ac3549b28',
#   '536ede72-28fd-4236-ac9a-b2cbcaebf2e0',
#   '55e9b73c-14e7-4de8-a624-080b72d12c03',
#   '7f7968b6-eebc-4178-b91a-0b037107c89b',
#   '0e390895-b20d-4507-ad66-32393565d86c',
#   'b6f3197c-b681-408f-80fe-a0fb8781fd06',
#   '436c91c8-fb7a-4000-91da-aef2c1b77ab1',
#   '201cd607-b0d4-4952-820b-0ff98bc1a49c',
#   'a62f4db7-0986-4a7a-a464-796dc1aeff44',
#   '0e2241b8-6dfa-410d-b363-27054c1204fe',
#   'c4fcea83-a8f2-472e-9b8b-51128e23867d',
#   '83b2bcf7-6215-4d50-b44a-fd93734922e9',
#   '03e490f9-8044-452a-9d9e-e3e6cb6dd5f0',
#   'a51b43ca-7876-4c2e-a376-7f452273d8da',
#   '9acda72b-3d36-4536-af5d-00defe8f3385',
#   '82847b02-0571-4193-977d-d9000f667734',
#   'b46255da-6b20-4a11-bddf-d17cfc2de770',
#   '09f1210f-5304-42db-84e8-5bd8cbed40b7',
#   '0ab9efcf-2c6e-4eb3-9821-54f150b4f1fb',
#   'f068770e-99f5-441f-a014-0f1578675cba',
#   'c88b1a45-4154-4bc4-ae48-4791d3d139ef',
#   'ccaae9ba-dea4-4d3a-af3b-f02a222da16e',
#   '6c691455-575c-499b-ba44-1b16266c9f77',
#   '6e3ec1d8-5785-4530-8ebd-77e38f27e956',
#   '078004b0-5df8-41fd-8507-c86932ceb962',
#   'dcb261a7-5bac-4086-bf78-5c36e8a37d8e',
#   'c94af502-0827-49c8-92c9-d1d5253d1151',
#   '4c762a0a-d84b-40f5-907b-453c2799c998',
#   '36ac4c8b-7144-4d42-9f74-1144d96d743a',
#   '80eaef05-f41d-47c7-8fc2-547a1021b088',
#   '4af76907-3ca9-4373-b07c-db19dcb8550b',
#   '99ceeeba-aa0e-4b58-9c6f-decc4fc98705',
#   '328ab554-ed3d-41f6-aef9-151aa14f4c6b',
#   '641d5d5a-eb28-4cde-b313-345ce9f0e990',
#   'c2122330-020a-4c5b-be37-85769a8498ad',
#   'db2697a5-94ac-49e5-8d67-b6da1df65b16',
#   '7e7f3d9f-f719-40a0-9fc1-024999d94d2a',
#   'f0e52cd7-95e5-4c89-8bbd-e2a860be6785',
#   'c2e67e45-bc6e-4acb-a279-3f79556ab855',
#   '370541f7-d735-42f2-8653-f5edb03fee10',
#   '5a90f7e7-7e50-47d9-a403-15c9bb59aec3',
#   '4a621549-cf91-4904-b218-ad45e2dad12f',
#   '9fdb36fe-3c31-41e8-b0c6-073a42cc5045',
#   '2e246641-5ef0-4729-a5d9-f27f0eb3dbfb',
#   'a62e19e9-c47c-475f-90af-53cf5d1af90f',
#   'ac91cb9e-2043-4f28-9161-df676546f172',
#   'f1108433-69de-4f68-9f9f-3ad8238ac4e6',
#   'c6581844-9e1a-4546-9ca4-c48c4a7fd599',
#   'bf9108cc-b995-44ac-90e0-2bcaa96b0b08',
#   'a8c78894-8498-4068-9fb9-41ac2bf7b931',
#   'cbd3ca35-58e3-448f-89de-1946b85ee49f',
#   'dcbf4c3e-8f7e-4a01-a003-b231da1f1e5a',
#   'de9552e4-a1ac-49b4-8775-6b99e6f4186e',
#   '5c12b348-4e1d-4cd7-a776-cc9dbab24f9e',
#   'cb7257e9-2820-425f-9968-7efb984869aa',
#   '19643cf9-62e2-4ab2-9d8c-29e94d0042fe',
#   'e8255e26-b304-4a1a-9c66-b98185fd87d4',
#   'abfc5366-a996-4950-b668-acfd3c6cd00c',
#   'a11d22f4-118d-43d2-969d-dedc4c6feef8',
#   'e7d44290-6018-4e8b-a424-ab90d406ab0a',
#   '1f50825a-dc9c-4f8a-bce0-0e6cbdcb59ad',
#   'accff6fa-2a28-4f46-b7cc-ef918e5557b5',
#   '7fc01bfc-396f-4e73-9c35-740b8bfbeb8a',
#   '75c7c9db-c77f-4b6b-989a-2009fb834c7c',
#   '3464b85e-a582-454d-a59e-85d5cfe4c8ec',
#   'e02dbe77-dd20-4c71-a5b5-a5460b81a9a1',
#   '13f5e480-a3a0-44ab-bd4e-3197100d6791',
#   'b15cf38a-633c-4ab8-a418-1ac507c1d4a7',
#   '5f36e194-3d0a-4d0e-a3f6-1834b8672cb2',
#   '7bb08b2b-e269-4883-9990-b00697c613b6',
#   '8faefb80-8381-45ad-af23-9c3b8eaacb77',
#   'b120b40c-34ed-4070-95f0-e32b289ed749',
#   'bf255caf-e57a-4ab2-ba4c-b07c33a9315e',
#   '9b247c7b-ff6b-4a63-9f64-d0d4b87db47b',
#   '90d66660-9203-48a4-b92e-ff84373b017a',
#   '55a17c68-3950-4bee-8727-4fb7c881c7db',
#   'bac596f5-bf6d-4eab-8ef2-b874bcfb9529',
#   '272b9620-8c5c-409d-afdc-b878d177de58',
#   '4da74f4d-371c-4fc0-bcc8-f867fa87afb1',
#   '294ffd2a-c399-4a0d-8b7b-39b02c2ce1b9',
#   '884c4a5b-bb9b-4936-af24-45bf3967526d',
#   '6631b1c0-d84e-4997-ac8e-5e66df3559a7',
#   '37bd996f-e273-4988-9113-93c8c92fb17a',
#   '2730d97a-f823-4176-88c8-50119aab55f7',
#   '3fee012e-0c72-468d-a974-28ff2106219e',
#   'd22cba14-d53c-48c1-9a20-cad579bbef6c',
#   'e55f9900-a2d4-4b40-b994-d7626bb6c31c',
#   '55cf10ca-2c99-444e-8616-4b9435f67d31',
#   'c70e538f-e567-4412-86a2-e1741771ce11',
#   '8648b42e-d7fa-496c-89e5-a42392d291b0',
#   'b5d3e31e-57f3-4932-b60d-d64e1082d9e7',
#   'bfd996a5-2e6f-4434-843e-8e5334b6e8e5',
#   '977a3079-6e87-4cbf-89c0-8fdf951c87fb',
#   'a711432d-68b3-42c6-ac0f-762f3789f89a',
#   '3b7e7ec1-01c7-49af-9468-56bd7f3105b2',
#   '8ca5c93f-b093-4abd-be78-1c6504533055',
#   'c73b3408-4f79-4d34-9be0-7560f7f65f71',
#   'aa74512e-2141-4345-95c4-4370c84d26d7',
#   '89645180-f502-40df-b4e7-d56d0d0d9fb6',
#   '0b4c2827-18c1-4f8d-b5e1-3d9c24426da9',
#   '37dadba2-46e0-4b39-ba0d-d81a4ae157d4',
#   '34798338-ef52-4984-9b31-241db3aec664',
#   '2dfc28e7-f094-46cd-98ee-248a31639a3c',
#   '50fabb34-738a-410d-9552-0e04145f79e7',
#   '2ab87e01-0dfe-4156-a0ea-001729ff35b1',
#   'd525a5ec-207d-45d9-ac02-b162dd566cc4',
#   'd430b037-b38b-422f-816c-07b8a6f85e4f',
#   '7463e1fd-4cf8-4951-8ae5-b0bb8173d2c6',
#   '6b9947a6-0ab0-43c4-8683-0aac945a01df',
#   '6399be3d-dd48-428f-870f-714e3e6d8353',
#   'b4d622b5-179f-410b-8a36-dac204735a83',
#   '3778c1ca-3801-4363-b9a8-d857ff31e1fb',
#   '6c19f872-ca18-4fb4-a18b-11d896287471',
#   '259a2d9c-4d26-4b24-aadf-d7bb7c283696',
#   'a910b3fa-f57a-4c19-a435-63690c43c29a',
#   'c62d78ad-52b3-4259-b827-d79dd5f5bf16',
#   '746dbf57-9e22-4b3f-a40d-88bfbd60292b',
#   '5d6303f9-242f-4f19-b6f5-8246ebb8191c',
#   '5acd800b-6fc9-4622-bd08-dfa9c19046a6',
#   '444d8d01-1911-4c21-a98f-3c16b257455a',
#   'eefa9a78-92ce-4d0a-ab55-9e7a27e86d10',
#   '70af077e-239b-410b-ab77-18f0bac5d074',
#   'af241716-6f8b-4950-8ffa-ba62f3202a11',
#   'ad36b720-9bd5-4bf0-a0b7-4ed8bc93ece5',
#   '79f6d9e0-491b-476c-a7ad-828fd81dcb76',
#   'c7af86cb-747a-49ac-b39c-6b9057b0a48f',
#   'ae7db2cc-0dbb-47bc-917a-9887d5d48122',
#   '248cc775-f410-44b3-8061-decdca5c5dde',
#   '77b17359-d45a-47a7-a3ff-c6f32a66a7cd',
#   '73712f47-b7c8-4442-b524-55688a714ef5',
#   '049cb500-c403-47c8-9452-3153ee5e6073',
#   '8033c24b-cd0d-432a-8031-8e428cdfd502',
#   'cca29241-0fa3-4c46-9081-4664369b5e08',
#   'db722708-82ea-4ffc-82a6-014ae24628c2',
#   '5b06d75c-3818-4859-9be6-2268d7118fa6',
#   '3d844af1-67c2-4f56-ab5c-c1319649054e',
#   'abb632b1-f866-4672-803c-e4d934244c75',
#   'd1e58bef-9248-44a6-9271-5b698159be19',
#   '6f211f31-992f-493a-be68-fb9a6ccb559a',
#   'ead412b4-4168-401f-bc2b-20b397931e06',
#   'db348cc2-ebab-4d06-b752-a70498fc22af',
#   '81470f3d-0fc2-4fd9-a387-151b4e81deaa',
#   '2a445bc2-4897-4a45-a5c7-29a105b6cd1e',
#   '21353e4b-748a-4174-990b-fc60636392df',
#   '53e95687-637c-44e1-b144-b5defc76f13c',
#   '9cd547c8-0c4f-44e3-9a78-16a06c9cacd9',
#   'a0b3b79c-5251-410e-af60-d23f5801b2f7',
#   '57ab793c-aff3-46da-83f5-2ff6b1efaaea',
#   'f7844caa-b28c-4b5a-883c-c3c564d994e7',
#   '87ed4688-f361-41a7-928d-e65ea51a5cc2',
#   '94264e7e-a17a-4fae-a31c-1b5a16e7b1c1',
#   '606ba8f9-2680-48f3-ba32-88afc5e90abe',
#   '918396c8-7105-49ac-b12b-69a411972342',
#   '0a5da52a-9c3f-417e-89ab-f284701d3016',
#   'c170cf06-29c4-41fd-8311-3c10c26a1a42',
#   'f8bc1e3e-120a-41a9-867b-19f994af0cfe',
#   'd120aa35-cc54-4690-9208-0d6cce9de71c',
#   'dc2902b1-7833-40a6-887f-9bd539514def',
#   '5b52711a-ed68-4c0d-b9e4-b7fac9a11ce0',
#   '428fde9d-53e9-42e1-8c82-2386c13033cf',
#   '5d0e92bf-56df-4e74-8624-18e8902a80e9',
#   'cc95a1ff-739d-4e31-b1d1-62d2ad4252a4',
#   '2b3877cc-afb3-4c87-a407-26dcaba6db34',
#   'ec61a747-3976-4571-971c-b04902fe83e5',
#   '6e6ce1c4-7186-4751-9f3b-771978422b7a',
#   '08452d15-8d92-467c-b19e-8c39f32f0f87',
#   'ce2eff48-7011-4cb5-8114-fa11551e5585',
#   'cfc979e0-a91b-4ee2-b2b9-19ecfcf9160e',
#   '4368b3e1-5bca-4da5-a11e-103a981d9b91',
#   '0d88bb94-58aa-45e5-ab6a-29a5c9ceb2ad',
#   'ab15f132-f434-4067-b428-fc0e22b6235e',
#   'e6da106d-db5d-46d0-8bd8-a07ae6e5001f',
#   '09217a19-027a-49d8-9419-dfdaf1618168',
#   '8e3ab946-8216-4078-81b9-9d510ca7870e',
#   '1eeb0d9a-bcae-4eff-bd92-d97056cf04fa',
#   'ec0a9d08-e94a-42cf-95ac-79b755d1979d',
#   'a3c68e52-7a3a-4009-a977-1e89423679be',
#   '6614a834-742c-4bd3-b4c6-12bd2dac0b45',
#   '4834e8b2-2994-470e-af5b-5514c2a02cc4',
#   '375cc783-5fcf-494b-8599-832f4316dcb6',
#   '2c7e4761-faf0-4bc7-86c7-5d09dbde15c4',
#   '5f3f951c-1b1d-44f5-bde5-59c7dcd10d8b',
#   '724de4bc-c754-4a60-90f1-2788dd9cbf3b',
#   '7c19e18e-bedc-4941-b70c-516eef1a2932',
#   'f4d22541-f513-49d9-9772-2b80f7de20f5',
#   '8037dd69-100b-44cc-8e25-1a24c5e18150',
#   '15f69dd6-4f61-4a03-aad3-8ad49b87e2b7',
#   'e0846f08-7bf7-4bee-ae74-b3f6c35685b6',
#   '6342dd77-f54c-4de0-ba9a-a983cebf3be2',
#   '8a36423c-2189-4d16-b639-1f0c999c3507',
#   '2c49bdbd-33f9-4af5-91d5-17590976e076',
#   'c1112c13-ef3c-4a8b-8d1f-6f9c8d011a00',
#   '3b993256-cf66-4130-9322-d0c8477ab2c7',
#   'd19560e3-b58a-4c84-89a5-aeba22ba71fa',
#   '8301de42-a3c4-47c7-a8cd-07bf4906c614',
#   'db076256-7edb-4272-9b2d-5efade224865',
#   'b60705cf-70de-416c-abe8-11ceba675450',
#   'baa1c00d-87f9-4e12-9c89-0306722bd1c0',
#   'e41141d8-ad39-4e3d-ab33-7c20a07ab172',
#   'c032f43a-d62c-4807-b33e-2ff768f92f93',
#   '6b27492b-bffb-4ed5-b6cb-d1281c504063',
#   '818b99de-dbe4-4374-a7f5-42a8067a09ba',
#   '1c39daab-36ea-47fd-a126-dd709a3642c3',
#   'edd5fe37-9edd-4631-ac0d-441ced41232c',
#   '0ea5bd43-f30d-4372-8f99-07528d2d5a16',
#   '6e0877a4-e47f-404f-a16d-84701c3c8d80',
#   'e3431b1c-93a5-4245-b211-d0d516fc039c',
#   '0c2868e8-0bc8-4482-9f08-193dab00a965',
#   'f1e427a5-bb24-44fa-9fb3-0be1c6b49647',
#   'ce4598ee-e008-48af-bb60-a086149d2a95',
#   '596cc2a1-9d55-451a-b48e-8b263f2c5fdb',
#   '799e0e78-56ff-41b3-9f44-d13eb67f06f6',
#   'a9b9dc33-9110-4847-b938-27b28f6fc31c',
#   '57e7929c-8206-475b-8403-747e1960ec0a',
#   '230ae862-952f-4717-b777-a83001045183',
#   '8558aa9b-0949-4554-8a1a-2c32d194196d',
#   '2adfe9ea-54ab-443c-a91a-34c9474455e4',
#   '710efaa8-2903-43f2-a471-defd9b3a0791',
#   '86b34b33-6bb3-4f6f-8fd0-4d229edf1ec7',
#   'fb7b032f-7ebe-4913-a9f6-98e6545dd31b',
#   '1d7d2d76-c1c8-4c28-90e0-10bf22b129bd',
#   'e44eb373-b9b2-4c82-b180-2be69ded7b6c',
#   'b62effc7-48e7-4a43-8ed8-95b8dca99cac',
#   '9bab482c-8867-4561-aaf3-2188078927fc',
#   'fe1cd334-eeaa-464a-a7ce-442f4aed7711',
#   'f13ae731-2716-47bb-bbbc-df4a17ef4fe0',
#   '4c861b0d-1da6-45cd-b618-4793e4ed0fab',
#   '965bd21d-e602-4253-bd72-bc4a8cb079a1',
#   '78c4bdee-7ef8-46e3-ae02-ee5396f0db72',
#   '8b8af215-e63d-4bab-a1b8-b4eb2de86f55',
#   '6f30313b-2898-48ce-bae2-47102c80552a',
#   '33dfa8dd-b465-41b0-8f95-bacef215983c',
#   '4913e261-7fc6-4bb3-945c-9c0b5a97f786',
#   'ac9f503e-2f9f-4935-b5b2-24cbdd45ab41',
#   'ed47c40b-e30f-4d75-827a-bce69b7c8499',
#   '858add33-143b-4754-87db-3ce61b6a0e76',
#   'aca26faf-e78a-40f7-b762-6f7ce2eaf226',
#   'ffafeb3c-afb0-4eba-b60e-dddc8c907777',
#   '1262d847-aaac-416d-b281-f203d0b1a783',
#   '93b5b3e8-c5bd-456b-8ca2-b004fe89cee3',
#   '594de069-2515-48b1-b8b9-28889164b272',
#   '9a8e9343-73f0-4ad9-9026-a45df5441238',
#   'fb2c65fa-ecdd-4e7c-8a4c-d8cb207f025a',
#   'f6bda797-841b-41f4-be40-a93c01e9302a',
#   '0d8091e0-2ff1-4c66-8d8b-e83fc4ea04ad',
#   '3f9d4068-e5d5-42ba-b60d-d9f46d799559',
#   '93ec0e21-5496-4fca-9182-13480f29e6c5',
#   '768d1c5c-1ce4-44ac-bb99-9c37983a1913',
#   '7378b80b-98bc-4945-a2da-200ae0deae1a',
#   'f638ddb7-9d33-43f1-86dd-dcd8b7d6f03c',
#   '3b65ca4b-759b-46b3-8d03-25a9a6b21eed',
#   'c94ea373-4ea9-4736-8658-289a366a104a',
#   '22ad74be-7f8b-4932-a789-33c12e88544f',
#   'a1c54c56-5b56-4263-ba6f-378cf7807551',
#   '477489f6-b8ab-4df8-ad88-7a8ada833905',
#   'd3589094-4c35-44c7-94b0-e4a9f6adebe1',
#   '9a073b8b-e8de-431d-9ec9-87d649a3c050',
#   'd021251d-ab96-4c99-ac17-01ee9ed3f768',
#   'eea2cd7a-3888-4520-aee4-1cdaa374a066',
#   'c1c40c65-8790-4535-80cf-63eb61168562',
#   '95a83ba8-cf25-49bc-ad8c-c05c5f2e5f2c',
#   '8e226bc4-c813-4ac8-8d53-f88a77699527',
#   'daa33e8d-6b84-4a76-94b8-818b48dcf40b',
#   'cba5b606-da42-4e48-8043-4a7807e40d4b',
#   '8e0883ff-260a-4722-9168-9e7fc552e532',
#   '95e820ec-a9fa-440d-b305-39bc242e3831',
#   '0b84d95d-c3ea-46e0-9204-a4e7288dc112',
#   '0684c04d-1792-41bc-a122-25b76413c4f1',
#   'fac3183b-a1cc-4da4-9e56-be178ac263fc',
#   '673b1759-881d-41f9-8b23-284e75f0bfc4',
#   '10a78e8b-b7ff-4e13-adf6-55ceb0989d9a',
#   '1c8231f9-d4fa-4971-8dbd-77c21022046b',
#   '08068f5b-8739-40a9-8fd9-200bf9976f95',
#   '4da30f44-3bc1-4083-a173-de72f6839ebc',
#   '96f4045a-6fe3-4e8a-b401-49689194311e',
#   '3604dbed-e90f-4265-b16c-c753124ee051',
#   'd7af3178-cbfc-4534-b3ae-f42390813266',
#   'e84fa164-4bf0-469e-9572-599fe1678364',
#   '4ddba357-0eeb-4803-a896-2e7e67705cd5',
#   '302f26fa-60f2-42b1-badb-76825f59f325',
#   '0bdbe0c8-e388-4fa0-8f3d-196829efafaf',
#   '82b8ebe9-f213-4005-81fa-202cbefcc1ba',
#   '2b1f1dc3-3133-4d71-ad9a-8c040bf5d880',
#   '17cee7e5-8382-472b-8edf-751013373ef6',
#   '34353208-a7fd-48aa-9872-c53475a0d9e0',
#   '3ea7cb12-50bb-4833-bff7-0f152667c6aa',
#   '7fe09c74-1be3-4f68-86cb-af54a21c737a',
#   '29eeb6d5-9948-434e-833f-769bd8e8687d',
#   '3f5a0049-7e35-4d9a-b39d-f16d6b816f83',
#   '64e409a6-a087-454e-a8e6-a3f5634524d1',
#   'c5057629-d728-4258-a1d4-7fd08700d362',
#   '95dd51b8-2d51-49a0-872a-99f0ec42ecaa',
#   '3caa397f-a540-4a59-843b-e6f32bb93713',
#   '6bab9ead-f2a9-4c94-afd8-28804cb9b5cd',
#   '9eb4c310-7c9a-4d1e-a09c-6d56eaefaac7',
#   'f9b0a57f-2aff-44ba-86d9-6bd4aed7dd2b',
#   'c4e0be11-3b39-4177-b185-2849da7abcb1',
#   'a8136dc4-b4d7-42f8-a17e-e6e1a91374a9',
#   'fee723c9-5ab1-486d-b5b3-a9feaccdebe4',
#   'e5b021b7-826b-4858-84c9-9155a446b35c',
#   '6429be45-875b-4fec-a99a-b1f7294b3ecd',
#   '43ba1a43-fb9b-4b44-b5f7-8641fa14fb0b',
#   '9d08f321-4046-415a-8437-d5125c33c090',
#   '5dc9a7f3-d483-4715-ae71-8fe57ca5310f',
#   '24bad9ce-0055-4aaa-9152-026cb6bc3a7e',
#   '5439f7d6-e7c0-4642-82ca-da33f4f44dda',
#   'f6bf372a-b27f-4eb2-b57a-4fa3101b082d',
#   'e5fad004-7d65-44ab-a347-6f1a8d293ef5',
#   'b05c075b-e3fc-43f6-b716-2fca44d81a75',
#   '10ed3426-0ec1-436a-aedd-cb132e4948d8',
#   '314c88aa-09d9-4614-b802-19a031387cf9',
#   'da04e8c9-ad93-4f53-a99c-d1972710d4ed',
#   'b3d3f07d-880f-4802-9341-4971fdbf6817',
#   '7c22c79a-7cc7-4b8a-8472-1c83d4e5c7a4',
#   '9bbb7cec-ca60-4231-9d09-e9adf89f4e75',
#   'b2c9855f-c267-4a4f-96f0-5e247da3b602',
#   '42d92687-4f14-4bc6-b36b-165a004df0d9',
#   '1cf9ced6-034b-4637-a47b-a381538f9d9e',
#   '07b057d1-450d-40ff-9564-38c3318a692f',
#   'f20e4ff0-9c64-4899-bd15-aea6234db628',
#   '9f0343fc-e2bc-4e2e-96c6-2a900d08902f',
#   'c42768aa-3510-465f-93b6-2c9b3778aecb',
#   'c436c61d-7177-4980-8d0b-b126690ae7db',
#   'dcabbcdc-4eec-4c65-9311-5669c0045d6a',
#   '29d2724d-d760-4348-bbdb-e5aaa5a5b0ae',
#   'c39d727b-23a7-4c09-8e16-b0dedc3f4783',
#   '341f015b-3e43-493c-a701-8fbabea8f9a8',
#   'cbc40d1d-3a43-4a83-a1d5-58342dc3cb2e',
#   'fabb675d-4782-4c82-b566-ef7ef7fee98c',
#   'a92f359c-4485-46e3-9839-ae453a7c3ebe',
#   '0a1e9203-fd66-4eb3-9528-637552639b69',
#   '1299269e-cb9f-4173-91aa-4ee9b6f87129',
#   '3663dfce-97f6-46bc-b27b-9a779af11756',
#   '24751de1-0771-4631-85a6-0d2381b98426',
#   '6bc0be85-6929-4ce8-8f6a-9416c0798a94',
#   'cc908d0a-b21e-49ce-aceb-b21d9cb7f0be',
#   '383e6db6-1ae7-4960-b4a6-0ccb3592bee2',
#   '217f2953-7da5-40e3-accd-b0f52f5ab034',
#   'd9da2711-be93-4667-8e7a-4321838da355',
#   '783aefe5-8047-42e2-b95d-4e7aa6fbba42',
#   '97c82aad-2356-42f4-86e6-d62ba0959bc8',
#   '537dd766-6914-4bff-beb6-aaf9ee9c4f15',
#   'a3043793-4dcf-4fe9-8f95-ae5b84b709f6',
#   'be7eba82-6df2-4bb2-a50e-b7e27d2bd293',
#   '74612b9e-d94c-4c04-b7d2-5639fad3bd5f',
#   'cdcdd00e-b295-4970-95f8-fdb584ac9dd4',
#   '0e35495f-9f83-43f7-adb5-a332290a0310',
#   '8eaef29b-5b60-4b72-977c-1fa382ff3f1e',
#   'd7d33e72-19ad-49a7-bef2-9f0480885942',
#   'a4bf1df1-be08-433d-bdb2-3be2f77dd8f5',
#   '0a9d8816-980e-4e93-a962-35cb5fbe0875',
#   'b6113438-7082-42ce-b50d-cfa0b0015698',
#   'd57a34be-e02e-469a-bd67-005b924a8e10',
#   'fc65e7f8-d493-4c1c-b271-c8675deed04b',
#   'eb9a602b-8d95-407a-8cd4-4b2eb95f8700',
#   '7d9300ac-5a3e-4eca-8529-dc397dcbe2cf',
#   'd9df0fbd-c63d-4b14-a80a-1a143c29dd27',
#   '1ef47e37-6d2b-4042-9482-3eeab6f06065',
#   'ecf002ca-abd5-4ddf-a8f1-6a7013de98ef',
#   'e181e567-3382-48ae-b57a-a77797bd829c',
#   '9536f1b5-5839-4a5c-8772-9e998c8b69a8',
#   'b48a7676-e1f2-4303-b3e3-7dd3e85831d5',
#   'ab5352cf-7a31-4743-a2f2-da95e884a717',
#   '0f26618f-4f13-43bb-a90e-47d9c856ac1b',
#   '34178ed0-5c90-4be1-b03a-dd5f8d6bd8da',
#   '7c6a0c14-2e5c-4cd9-b7a9-8734453dcdec',
#   '968569c9-f048-4d08-bd1e-dee41c3bfbd5',
#   'fab2e621-ac9e-4915-b9d4-ce5ce97e0dc5',
#   '1d9792c5-22ef-406e-9517-f8a147d0e070',
#   '7fceeb62-1648-46bc-9b47-5cd8c45b02f7',
#   'ecd5119f-95a6-42ca-a9b6-bde85e5c8d63',
#   '66f923c3-ae8d-4825-b2d3-0101b49104e8',
#   '3f7eb2e2-33c3-489c-add5-d6aa68c91a6b',
#   '0efb08c7-9031-4e48-ae7e-e0de4cb63e52',
#   '7a76f2a8-e9ba-4b64-adb9-2bc676a6cad3',
#   'e96b6446-bfa3-4a5d-a449-3fbbacfb449d',
#   'a4851d5e-03f0-4cab-8513-e3ad06504296',
#   '4935708e-1eb8-42d0-b2e6-f9e005e36789',
#   '67bbbb78-cb6b-4bba-9ab0-1e12af0fb2aa',
#   '2c550e8c-8dc5-4cc6-b125-0565d1d643fc',
#   '0dffe70d-ace3-479a-9c96-1a78bd23e0d2',
#   'f176bad8-4d45-46c2-a9bf-f62d8a06a245',
#   'b7d9a965-414e-42ec-be48-782ce66c4646',
#   '5e7d7256-3c7c-47e1-9d67-dfa95aafaa87',
#   '83a840fc-f78b-46c8-9c9c-3741dbf42028',
#   'b1cf773d-29c2-4515-9dc5-ee54d8c4d60e',
#   'f253e428-f8c0-463e-9c7e-4fcf35d87087',
#   '55327070-2442-456f-bba8-269a6020510d',
#   'e8d67c0d-3d8d-43f2-8547-551928b9ee59',
#   '3d871ec5-fa88-43d4-990b-2cab75f6ccd1',
#   '7d64019a-8d88-4642-9820-d588822121fe',
#   '86d764bd-d614-4b2d-9784-8c43de3e6735',
#   'bf6a0239-142b-410d-a3bb-6ef7952aef70',
#   'a2ca35b2-da46-496e-9190-eef106abd212',
#   '24ab51e4-628a-4a88-8776-09e0108db7e4',
#   '0b731efd-6225-46d6-8161-501411ed2e70',
#   '539df370-cf07-4fb8-b9f1-7c9ffcc8711f',
#   '0527e8b8-883f-49c9-bde2-b49fcb64edbb',
#   '5a71ad40-cb85-49d8-b766-0efe330635b6',
#   'c7537564-1511-4cbc-ac9f-2903a4bdb0b2',
#   'da75bf66-3572-455f-a0d1-c93c2342bb18',
#   '01cf7dcf-c3a6-4029-a927-80e7828ac7b4',
#   '9eaa737a-3adb-48c2-8c02-69cb32eb6089',
#   'f4f21e75-d99c-4d92-811f-8f3977f5aa7b',
#   'ecb72f32-ece2-420d-b7e3-8b1bd8b67a6c',
#   '004b78c9-4457-4066-84ae-ef1d8026bc81',
#   '92640192-716c-4d44-8de0-cb2574b8a876',
#   '54feaffd-7157-4d2c-957c-9d856791f9bb',
#   '5ca8f3ae-eac1-4f31-b71a-765066db6036',
#   'ba081b1c-c629-4f4a-9a65-f1df5b467409',
#   '0cf7abd7-e449-4329-a538-e110c90f34f2',
#   '33c6adf5-dcff-4c13-b5c0-c4eacb65a80d',
#   '1098df25-8c0e-4ac3-bf04-c6d9c17d3bfa',
#   'cae2b87a-9759-435c-9b0c-49d11e70d713',
#   'e4b2efc0-f7bc-40ad-bdcf-bb1f15759863',
#   'fb721edb-0884-4918-b1e1-61ae9545d817',
#   '67ff4b91-852c-49f3-be92-9c26368ec49f',
#   '2787ea26-a191-4b1b-b82c-14c87da11723',
#   '22fcc2bd-c6f6-47ec-8491-a7d7d2a7ece2',
#   '26f21ef3-00d9-46cc-842c-88bb9522d173',
#   '0279251d-11d7-42fc-9149-332a04e3e4b4',
#   '6ddd2380-05c7-48fd-9b5b-054f30aedd33',
#   'b75e669b-201f-4d80-8809-1ba4a44a6b35',
#   '5e4b02d4-79a4-4fe8-abf4-318fcbdf1a64',
#   'e375305d-95e1-4996-9d75-a112c69475e8',
#   '6bfe41ec-d83f-40f2-b42a-3a4303608e2f',
#   'a175b126-a6ff-4eab-b6f9-09d31ad1b75e',
#   '93c8706b-5d8b-41b3-937e-47298706749b',
#   '6c66b227-a229-4655-b3a5-0fad8d05cacc',
#   'aaf6329d-070a-4809-9250-5b3307c21ea5',
#   'df707e04-2ce8-4ddb-b59b-03a27abb33ee',
#   '5815911e-825a-4b60-ac59-81b716be4fc0',
#   'e6a08057-1bab-44c9-aeb7-fef2e8043059',
#   'd1b675be-9c7c-4e7a-9a28-245cbd3a7956',
#   '8245657c-dcab-4124-a6c6-0221b6843c91',
#   'a2a6fc9f-8521-4511-9f27-ce60cb78af68',
#   'bebe9270-c649-4ffb-b1e8-6a4e48a916de',
#   '0978ebbb-d043-448c-a442-5b1e1ae74942',
#   'd174d7ef-45be-4c62-980f-b9707d308c03',
#   'd8b387d5-0f98-4054-be33-4b701960de50',
#   '028a9572-7c46-434c-9405-74ab9eb81a98',
#   '695fbb7f-7efe-4503-ae2c-dc0942660437',
#   '8c9df3f7-fc43-4661-8e62-99901e16547a',
#   '6464dbc7-f6f4-4160-8942-36e6381818bb',
#   '43f79691-b6f6-40f3-b100-b68b1312c279',
#   'e10db24d-f779-49c4-a167-21b8e0e700e1',
#   '1e8c8e27-8d58-411f-9905-15f3fcfc7943',
#   '7eabd995-a9b9-4c41-a9d6-fbd1da13bece',
#   '01fe03ba-0f5d-4d70-aa7a-3eb6729353d5',
#   'c6ebdbba-58a9-49dd-a763-f4c5c928e45e',
#   'e4c29626-4b27-444e-b7ec-63998997170e',
#   'c367e1a8-e4d5-4f10-8ae8-6884d00eda8e',
#   '8ba9a0b3-cf36-40c8-a947-ee751317f952',
#   '158b86d4-c6e2-4fa2-b5a6-db4bcc83d70b',
#   '0b28bcf0-e5a9-44d4-8ce4-0f8817230bc8',
#   '42760850-641a-45b3-bcde-3dba1c4e653e',
#   '12164341-75c3-40c1-aad9-d24f6c2d45a4',
#   'b2eee056-5117-4c22-a599-4d216969168c',
#   '33dc55b0-a134-40a5-9438-09652ce3186e',
#   '1af2b44c-0367-40bd-aaeb-dcef463c2adf',
#   'a395f95b-3f80-4a94-a12a-ee1c3bf419bb',
#   'ca9a0632-afd1-4120-9c7a-0efae9486d3f',
#   '45e05995-fba4-41b1-b67a-ada8743e7da7',
#   'e302c9f6-ee38-4202-9828-09f92cec300d',
#   '827b0901-7b3d-48b0-a2d8-e0c5dbf03f56',
#   '829d62af-3f89-44f2-909c-568d9cde55a9',
#   '2a664590-eab3-4a66-9e35-e13c3a12c0bf',
#   'c5008e75-7f25-449f-84a7-852eb0387aa3',
#   'acfae2c9-d268-4aca-b931-82b9a504630f',
#   'b986b141-65f1-4c1f-9739-b4a39046239b',
#   'b98605df-66b3-4b97-a604-c3f6f6e41c58',
#   '9e37a63c-1e13-4582-b445-6b3f04223eed',
#   '26b04137-bab9-4f0e-b36d-80524dc3eab4',
#   'f6b87e50-c7cf-4606-b514-d01279c587be',
#   'b8fd7b08-dbfd-4546-92e1-95af769a33de',
#   '14b3869f-2508-4bd1-900c-82ea08476f1b',
#   '6ec9e1a1-8e0b-401a-98db-6ab9099249fc',
#   'bda5e3e7-01d8-4f53-a850-fcd9cfc72963',
#   '879c612f-ca84-46dc-a847-fd718db6c60b',
#   'a27d6be3-82a4-49ba-9561-75da9d289700',
#   '2774e12c-3d54-403f-9b2c-ee1d4fe8b869',
#   'd6f2f6b6-7449-4265-960a-e2425034f434',
#   '32684625-2870-4d08-a3a0-02f424e965a6',
#   '154cf969-8ecd-4135-92b5-55adc1bfc9d3',
#   '2d72dd9a-db0d-4571-98e9-ca23b92f6e58',
#   'c846674a-1c04-4838-9b1a-1bd5e95362a1',
#   '0c702a30-eb1c-4b6d-82cb-8d7ddebec5e5',
#   '6fc25f53-7972-485c-874c-143666b11c28',
#   '03bcc610-888a-44f6-8268-0a4958178de9',
#   '13e71ede-891e-4906-952a-a26c4651e1a3',
#   '0232ad03-9717-4c3a-8400-59e141f29da3',
#   '88d1ddf1-5356-42a7-8dc7-98429b836773',
#   'e03c423d-27df-463b-9480-0f37d67529db',
#   'e3bac1c6-fc36-4808-a32a-f9da4636bbdc',
#   'f4302d0b-9129-4470-9765-9392ddb3524a',
#   'a19f39be-bb8d-4101-aa4d-aea69d463cb8',
#   '7da77d0b-c85d-4e54-ba8b-744cedb428f9',
#   '8af7fb69-91fb-43a0-8605-8a4a7f709669',
#   '9fe6d04f-414e-4f6d-95cb-731f7ea8a8d8',
#   'c059e988-47ae-4486-b084-a4ad83bb34b3',
#   '5e9a731b-7c4f-4946-a77b-203a285c2295',
#   'd8de983a-c714-4ae1-aa67-08993d827c5a',
#   '0e7934b3-9006-4c40-a4f7-d261e1ef03df',
#   '86212bd5-23cf-48c4-9c4f-d6e68b585f21',
#   '420161a9-9c79-4416-a5aa-291a90aff4a2',
#   'd5afd817-8090-4a9d-9579-f74c9a90a9ad',
#   'f3dca99b-9695-4f2d-8665-5f1043c21567',
#   'c39c577c-9dad-45bc-8747-ee4d5c1d056a',
#   'a5b1ab69-7b84-47e0-985d-8c211454ad91',
#   '247a2d7f-32e2-487e-9daa-930935431888',
#   '6d4204d5-4889-41b3-9d6f-5dd1bc6f6997',
#   'af7a6345-a5a5-4bee-a3d3-e54935fd6c18',
#   '280bfb89-c36f-4626-a091-8730a39e5c88',
#   '223aacb0-dbdc-4364-b13e-4a87ad59b7e9',
#   '39ce4183-c1c9-417a-9a78-6cac0aaa2c8d',
#   '85950203-0a91-457e-b004-4e4b3aa2032c',
#   '66e75f75-1f00-4351-833b-c1b30a46c014',
#   'dee3072c-c837-440a-9c11-fe652a9e87f6',
#   '28b093e1-dd42-4c64-b241-707f9f3bb589',
#   'e71896a9-8b3e-417d-9015-8fe1f8a28348',
#   'c4fd08d8-e77d-4692-a222-57140425db5c',
#   'b6e5bdb4-4337-4632-b7a8-7b19c2ea2122',
#   '396232ec-e622-45da-a137-66255f01ad58',
#   '57ae3298-4a63-4a9a-9633-0c155d7eef8b',
#   '8335b546-95ac-418d-9cf2-8d13f67073d5',
#   '138084ab-f630-430e-a881-17a05ff85ba4',
#   'd271b293-0316-43f6-ab44-a334812751a7',
#   'cc00b311-d523-4b3f-952c-9befe9cc391c',
#   '09108758-13d5-483d-8fbf-e461b0723516',
#   '0a8f540f-88cc-4b3b-bc0b-396e72116b68',
#   '8ceb1763-c00c-44f4-88c8-06ee35fd0464',
#   'a13ec294-3a5a-49cd-a2c3-6db287816d78',
#   'fbaf203f-c98b-4286-a5e2-5ab2dcb2f453',
#   'e1f890d0-08fe-4627-9323-0103394ca56c',
#   '7967d57a-e7aa-4c26-b731-d124285f7cb2',
#   '0d8f4bc2-ca66-4c45-a581-fc01e301b7af',
#   '9848afbe-a2d4-4a79-b9cb-250417c96927',
#   'bcfc0373-18c5-4a15-a5d6-d93786440e02',
#   'fd739cb2-4fcd-48ec-85a8-e76786e4539e',
#   '15787f43-6f58-4cfe-a508-c3f644a24949',
#   '3f17a7c4-d37b-4b05-820c-1a044f1119b7',
#   '558e1f12-cc07-4c01-ab4d-29f75282114d',
#   'a239600a-bb43-4ee2-8e83-411a5f01852a',
#   'd982a5e1-b4e4-4303-b355-d1f62d89e346',
#   '5f042c9e-63fc-4ddb-bed7-ac388f5a52a9',
#   '434b53af-a82c-46c5-84ad-95c7292651e6',
#   'b846ac2c-a939-45aa-b7ea-69ddfba51f01',
#   'e8a9125f-bed1-4bd7-9944-314bcf75803d',
#   '7474bfe6-9cd6-46f6-851f-323a6f8de573',
#   '86358249-7f6b-456d-8b6b-fb26a8b3b558',
#   '5eb7e107-87d0-45f8-ad7d-be3161d5ed46',
#   '87bd7362-574a-46ba-ae1c-4b69cdf2bd30',
#   '4c7013e6-e1c5-431c-b922-da4ab2119517',
#   'de660614-6f47-4260-a2f5-17420e9b8d6a',
#   '7eff84db-7e5e-4429-a7c1-4f31726370f4',
#   '4ea6cc36-7223-4ace-b571-808d09009b03',
#   'd67a89e7-8bb3-4929-9f36-23362102dc0e',
#   '1a4df02a-ee47-4e24-a233-baba7f829942',
#   '8c6344a3-a1c5-4351-b4da-425a22cb2592',
#   '74f7dadb-497d-4208-bb58-65421b4bca8d',
#   '81a746ea-53f4-4add-8836-47ee1a3237b2',
#   '2098cfae-6315-42ef-8433-7a9cbb432fe1',
#   '24e9d90d-8464-40ad-a8e2-5ec2299790c3',
#   '47b16e1a-faac-4ce6-a472-5187054fd745',
#   '0947bb8d-7db8-4228-9822-f1ba6ec0083d',
#   'fd140105-3cb3-4cbb-8b65-781c6334bf37',
#   '1746b7fc-f87e-4243-9610-3a495ad8945f',
#   '15f1721f-8edc-4b5b-b25f-567385253040',
#   '701e6ecf-4502-46d6-bafe-dfe26efe0e7a',
#   'dc4a8b61-79df-4d6f-8695-98bb68673e31',
#   '2d93a70e-c110-440f-9ee4-ae71073375e6',
#   'c342daf3-fbab-4fd0-ba24-f1f416096c4c',
#   '4f307bee-c17c-4ebd-8579-b6064f0f2273',
#   '695dc95d-0210-4a93-880e-29fb5dedb4fa',
#   '9191c536-3a6e-4282-8eaa-ef5af8041011',
#   'dfa83ee7-5218-48a0-aeaf-a5940d1fd70c',
#   '94d75076-3241-4740-a04e-0bba9fad4f90',
#   '4e46c484-25a6-4c55-95c9-fc16f16e79d7',
#   '8638111a-9e39-4a09-97f9-5ee28667bde3',
#   'c4ac9015-a595-4510-9540-d361b7679133',
#   '395d769e-6b0b-491f-8106-ec638186c59e',
#   '1df51f83-4e3f-44ec-b9e2-8668c0c6b920',
#   'd832bdcb-a774-482c-9cf6-6161fec6cdd9',
#   '805c94a4-06f2-4c68-a2fb-7a957e7f2935',
#   'f894479c-db34-492c-a636-8428dad16150',
#   '3a235048-8848-48e3-bb64-b0485c7f793d',
#   '95095602-1077-4da9-b6de-e966c449c5b0',
#   '409b59f6-fb37-48cf-9963-b14ef0af69cd',
#   'f973bf31-8e92-418b-9409-962289a17631',
#   '3d6a7685-86cf-4b88-a1dd-64dfb87f8976',
#   'd02069cc-e252-4b30-aac7-879f8cc7d2b2',
#   '443acaea-c010-49bb-8c38-047ad480e935',
#   'ab240891-1dcf-4b88-aaf6-a594e8b8ce4d',
#   'd18c3d51-eda4-49c5-bf0e-c0f84efbf9fc',
#   'ffd745a9-ab42-48be-b34f-400dbf98b2d9',
#   '7ef5a0ef-4d9e-40ba-b384-df6cc4eb692d',
#   'b972e52d-e706-4b9d-9b8f-3d07d727626a',
#   'ec5e8b88-54d9-4054-938c-852db7f8e1bd',
#   'fab28c8c-b2ca-4cc8-ac30-3fcbc8fd035d',
#   '69cf339b-e928-4b9c-b122-1b822f813f44',
#   '1a7bffe9-1b5e-419e-b370-c2d9e18ee6cb',
#   '5c62ca73-b1d3-4c06-80f5-e55f7c57ba32',
#   '3273ce79-cc6c-42fe-8e30-c4f1d4522398',
#   '11636540-609f-44fc-979f-99ddb5bd69ac',
#   '120f2b42-a75d-4a1b-8ab7-047a8c5574d1',
#   '9cfccdd5-660c-459c-8475-51871a1ee558',
#   'f725126f-118b-4c75-9a79-faf8c61b5758',
#   '26a1b56a-5a31-4055-809a-c665cb3266c0',
#   '235c2494-71e8-4f38-84ea-669f56add7ba',
#   '4066a97d-0004-49a5-b8d9-788c40952b5f',
#   '01124ac5-43e1-4c69-8f9b-6cb425c93e50',
#   '0c2dc726-580f-4f34-97f7-fd110d0b5ec5',
#   '3375a1b7-2b4c-4cb4-b36b-3c47e598a3b7',
#   '51b093ee-5e0b-44fb-92a7-a558722d9c89',
#   '0479172c-6eb7-4d47-ae9a-eb0bcf512bc8',
#   '12fa7532-8a8e-41c9-b3ee-05ac9c858a07',
#   '5db3e586-abe1-407a-97e1-2ba98dc519d1',
#   '6f110aa2-88ab-4265-8e91-ff545413d61b',
#   'd8f35c22-ff54-4408-af2b-207717b18294',
#   '412cbc71-52b6-4d19-8f88-c1847750ff23',
#   '0b7984ff-4566-4810-abae-52974b86c0fd',
#   '8a3bb6c1-2795-4faf-93a6-7b0c3d2423b5',
#   '1ed6280c-f9f9-4696-b57c-cb5a15aeac50',
#   '895f56c7-a6c7-41b0-8200-81cf629e357f',
#   'c86a1dde-25f5-4a5b-9ccf-1255c59bae15',
#   '8056f5f0-670a-441a-8661-3b167021d29d',
#   'c8b823f0-6108-430d-bce8-503275b52488',
#   'b66cc09e-9b7a-4a7d-b438-2aec095043c8',
#   '9573bc90-87f8-455b-8669-fd5e83512737',
#   'd54743b3-6202-409d-be38-e218d30605f1',
#   '1b505df6-3e82-43c6-b71d-219190a5f9fd',
#   'fd377f06-9c7a-4ff4-97de-673185f59e69',
#   '8f1cadf8-ef19-4116-b7b4-6119dd11ebd3',
#   '4d623484-f7f1-4246-b7ba-6c701e45c94d',
#   '6e687f71-9561-4293-9d23-e2c7a2e9e958',
#   '936c26ea-a78d-4719-938e-08412251cbf8',
#   '07ee9772-0a3d-42cf-920b-a0bee6409a44',
#   '93418e1b-991a-4797-9540-66b12972cae5',
#   '360bbd36-fbe2-4611-afb2-89f9a5b063a9',
#   'be240c6e-bb6b-4921-85a2-07e6fdeb99d0',
#   '00089b44-7cf7-437d-a5b7-fa2c76a91a69',
#   '0cf6bdf8-78e2-4460-a168-4003f950ee54',
#   '6f352a44-687b-4456-80c9-54d3768bc5ff',
#   '00fabc18-0d70-4cf1-83f3-306ee1e143ae',
#   'fbf77e1b-2a3c-4b0b-9a7a-42328ebfd23f',
#   '3a344f70-2fa4-4c40-a6b2-edec50097ec1',
#   '3f519031-2f1b-42a1-b8a9-918579808139',
#   'a06c7b99-4c4f-4753-a54c-c6020e8b7ff2',
#   'eac11dd9-bab1-4830-85de-7416b3b984ee',
#   '9e46bcf1-6b8b-42c9-b61e-bb303a765006',
#   '7365943d-4518-4ddd-b5e0-13915f904f5d',
#   'b18ce5dd-f193-49b2-9efe-1e70922f665b',
#   '7178d327-53fc-4c61-8396-ec74c363a495',
#   '21407a75-add6-4dd7-a8bf-2af08307aed4',
#   'e6a04b9b-efe6-4ffe-8e12-d30d0c20c406',
#   '3deb307d-bed0-40bf-b066-cf5e85999823',
#   '71d61f5a-feb8-4710-9f56-44c7a7eceeed',
#   '9ac8e304-159c-4e55-8d89-9bb61db479d7',
#   'f8720fe4-46ab-4104-93de-dc8b18d8b6e5',
#   '61125135-d659-4084-9a3c-fcba7036c987',
#   '8b9aa1e6-6328-4c7e-b631-61473472de85',
#   'bcaef317-5aa7-41ee-8e33-109f8676e88a',
#   '8be8a0cf-4466-4336-85dd-833656604055',
#   'daf2530f-edc7-47a0-a658-b596b5905147',
#   '9d71b075-abdf-4aba-916a-78a7e6beeff3',
#   '0cae4b6c-d6a5-4fac-9359-d192444010f9',
#   '297a73c9-307c-4971-b938-f0561f1fb57d',
#   '57a7b8dd-19a8-4dc7-a4c3-5d37fa5598c7',
#   '2a08f947-9f44-4bf6-90c5-8511fc1280a7',
#   '5143bdb1-8db2-461e-800c-7b5cceae98bb',
#   '7e8eaf86-08a0-4a25-b595-882155e7d1ab',
#   'c2ca52cc-ad3e-4514-8ef8-611031439d73',
#   '5c99690f-6468-461e-8132-baa5edd88ab2',
#   '8256a6bf-dbdc-4846-a61a-8a9127635a9f',
#   '47e739ff-f77e-4fe7-b3cb-e063fdda74da',
#   '79ca8e73-26f8-4da4-85cf-4a6404c9348e',
#   '3a633c9e-5444-4c75-9076-daa26474a9d2',
#   '4109f9bd-d56c-453a-99c2-8dd8e26eae8f',
#   '5fc97852-86a9-496f-962d-89981c4d6187',
#   '3f449dc8-bae9-48b2-92fe-c9af1391682b',
#   'f39477f9-b61c-4f97-8990-32859236e78d',
#   '5b799458-8e42-487e-a021-92a3bc362c83',
#   '40d70564-0ef8-4448-9254-c92f214c90ee',
#   '85c56dd0-34c5-4630-9da1-ca957a6f1aec',
#   '3f43886c-1442-4783-9626-415a0b337c08',
#   '2cf8b728-490f-4a9d-b427-94d8131eae84',
#   'd2226566-4e61-4f31-9e72-f3eb3ad8b962',
#   'bd2901bc-fabe-4523-88de-3d0c423d6017',
#   '7af584f1-a6ee-4a7c-8031-6420d0d1687f',
#   '6737d943-d913-4508-9f7f-93182ad424d1',
#   '5bd086ec-fe8c-49a5-8019-b98a09b95c5a',
#   'fb69d49c-4bdb-4a56-b548-56a04fd0413f',
#   '90d74e7c-4b8f-4c17-8238-f6bbeec29a4a',
#   'dbd25fbc-d9f0-49ae-8286-949a32532446',
#   '0747827d-b5cb-4438-bf9c-88e683a334cf',
#   '71bcec9c-7f5d-4142-a8f2-9ba6cb7249f2',
#   '2ee365a8-8546-49e3-aacf-61788e4a7e8e',
#   'bb6e983a-635e-44d9-92c1-b676b536e1a8',
#   '6fda3010-2cb5-4a04-a575-21d642416d4d',
#   'd8f41189-7849-4ab9-8a09-0bb2402eddd0',
#   '78a9c916-5dfc-4d92-9a51-ddd857c8aa87',
#   '15f56857-6efa-4405-b9d7-db117c935539',
#   '4eee5fcb-2cff-4c48-ae5b-9f9c5193dbb7',
#   '69c80827-c53b-47bc-b4a9-fb89386e9f54',
#   'ccaccf8d-b852-4993-98ae-d7ad0741f88e',
#   '53482ec3-5fef-4add-b439-82e475e24a89',
#   'fb7c723a-5e28-457a-b77a-6c80beaa9361',
#   'dae2d6cd-b99b-44d9-8599-b170d95c3d84',
#   'b63bbcc0-6efc-4cac-ad59-a2caeea6d8c0',
#   'd3020ceb-5e03-4c20-8f79-db854070aee6',
#   '969264d1-be66-4f6d-a240-e29ee5e74f10',
#   'ecf1ba86-5d6e-46be-a13b-b19bdf60953d',
#   '38b17585-39be-4eb5-9745-1e0de3619174',
#   'e564fc4f-a64a-4808-a57d-49c2300d8c3e',
#   'dcecf1a0-5abe-436f-a5bb-2e2af33fa8af',
#   '3f11ef3e-9bfb-40bf-bf31-e493b8922ef0',
#   '549067af-4b09-485f-a712-2b70d7725094',
#   '834251ae-ce1c-49ee-9335-6bb39ad7e819',
#   'e6556491-521d-4b8b-9c62-7b8ad09beabf',
#   '82b1a325-3ec5-4ff2-badf-21164c5cb2f0',
#   'db8e75ba-ba5c-46da-a20c-3fb4e19020d1',
#   'f7fe3a05-7bf9-4757-96ed-01acc1073dc9',
#   '1b3c450d-b6b6-41ed-adb0-b952ed650d94',
#   '47c76c31-f9d7-469c-a3bd-e637247deec7',
#   'dd4ff837-d42f-4a2f-a2a9-05f0baf16562',
#   'e76e5a63-ef63-4cf9-b220-d7979cd2071f',
#   '214b2581-8859-41d0-89d5-c21956fb33b0',
#   ...],
#  'embeddings': None,
#  'documents': ['브랜드: 할리스\n메뉴 특징: 밥류 분류에 속하는 리소토/리조또_스파이시 씨푸드 리조또 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 148kcal의 에너지를 냅니다.\n주요 성분: 단백질 5.81g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 할리스\n메뉴 특징: 밥류 분류에 속하는 리소토/리조또_치킨 크림 리조또 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 185kcal의 에너지를 냅니다.\n주요 성분: 단백질 6.22g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 피자알볼로\n메뉴 특징: 밥류 분류에 속하는 리소토/리조또_베이컨크림리조또 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 173kcal의 에너지를 냅니다.\n주요 성분: 단백질 3.71g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 굽네치킨\n메뉴 특징: 밥류 분류에 속하는 볶음밥_갈비천왕 치즈 치밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 208kcal의 에너지를 냅니다.\n주요 성분: 단백질 10.97g, 탄수화물 22.04g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 교촌치킨\n메뉴 특징: 밥류 분류에 속하는 볶음밥_달걀듬뿍 볶음밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 170kcal의 에너지를 냅니다.\n주요 성분: 단백질 5.38g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 교촌치킨\n메뉴 특징: 밥류 분류에 속하는 볶음밥_닭갈비 볶음밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 180kcal의 에너지를 냅니다.\n주요 성분: 단백질 5.0g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 굽네치킨\n메뉴 특징: 밥류 분류에 속하는 볶음밥_볼케이노 치즈 치밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 198kcal의 에너지를 냅니다.\n주요 성분: 단백질 12.81g, 탄수화물 20.66g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 교촌치킨\n메뉴 특징: 밥류 분류에 속하는 볶음밥_의성마늘 볶음밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 199kcal의 에너지를 냅니다.\n주요 성분: 단백질 3.41g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 봉수아피자\n메뉴 특징: 밥류 분류에 속하는 볶음밥_낙지볶음밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 182kcal의 에너지를 냅니다.\n주요 성분: 단백질 3.3g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 봉수아피자\n메뉴 특징: 밥류 분류에 속하는 볶음밥_불고기볶음밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 175kcal의 에너지를 냅니다.\n주요 성분: 단백질 3.8g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 봉수아피자\n메뉴 특징: 밥류 분류에 속하는 볶음밥_새우볶음밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 161kcal의 에너지를 냅니다.\n주요 성분: 단백질 2.6g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 피자알볼로\n메뉴 특징: 밥류 분류에 속하는 볶음밥_목동햄볶음밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 171kcal의 에너지를 냅니다.\n주요 성분: 단백질 3.09g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 할리스\n메뉴 특징: 밥류 분류에 속하는 오므라이스_수플레 오믈렛 라이스 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 167kcal의 에너지를 냅니다.\n주요 성분: 단백질 4.94g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 롯데리아\n메뉴 특징: 밥류 분류에 속하는 주먹밥_전주비빔라이스버거 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 201kcal의 에너지를 냅니다.\n주요 성분: 단백질 6.03g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 이디야\n메뉴 특징: 밥류 분류에 속하는 주먹밥_까르보나라 구운주먹밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 211kcal의 에너지를 냅니다.\n주요 성분: 단백질 6.0g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 이디야\n메뉴 특징: 밥류 분류에 속하는 주먹밥_매콤 로제 구운주먹밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 209kcal의 에너지를 냅니다.\n주요 성분: 단백질 5.0g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 노모어피자\n메뉴 특징: 밥류 분류에 속하는 김치 볶음밥_치즈오븐김치볶음밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 160kcal의 에너지를 냅니다.\n주요 성분: 단백질 8.29g, 탄수화물 16.5g, 지방 6.36g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 피자알볼로\n메뉴 특징: 밥류 분류에 속하는 김치 볶음밥_치즈오븐김치볶음밥 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 196kcal의 에너지를 냅니다.\n주요 성분: 단백질 7.87g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 요거트아이스크림의정석\n메뉴 특징: 빵 및 과자류 분류에 속하는 찹쌀떡_요아정 고구마크림 찹쌀떡 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 238kcal의 에너지를 냅니다.\n주요 성분: 단백질 2.5g, 탄수화물 45.0g, 지방 5.5g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 요거트아이스크림의정석\n메뉴 특징: 빵 및 과자류 분류에 속하는 찹쌀떡_요아정 딸기요거트크림 찹쌀떡 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 238kcal의 에너지를 냅니다.\n주요 성분: 단백질 2.5g, 탄수화물 45.0g, 지방 5.25g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 요거트아이스크림의정석\n메뉴 특징: 빵 및 과자류 분류에 속하는 찹쌀떡_요아정 쑥팥크림 찹쌀떡 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 263kcal의 에너지를 냅니다.\n주요 성분: 단백질 5.0g, 탄수화물 47.5g, 지방 5.5g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 요거트아이스크림의정석\n메뉴 특징: 빵 및 과자류 분류에 속하는 찹쌀떡_요아정 카스테라 생크림 찹쌀떡 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 250kcal의 에너지를 냅니다.\n주요 성분: 단백질 2.5g, 탄수화물 42.5g, 지방 7.25g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 파리바게뜨\n메뉴 특징: 빵 및 과자류 분류에 속하는 감자빵_강원도알감자빵 (5개입) 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 244kcal의 에너지를 냅니다.\n주요 성분: 단백질 3.13g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 파리바게뜨\n메뉴 특징: 빵 및 과자류 분류에 속하는 감자빵_강원도알감자빵 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 250kcal의 에너지를 냅니다.\n주요 성분: 단백질 3.13g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 송사부수제쌀고로케\n메뉴 특징: 빵 및 과자류 분류에 속하는 감자빵_감자쫀득볼 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 313kcal의 에너지를 냅니다.\n주요 성분: 단백질 3.95g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 못난이꽈배기\n메뉴 특징: 빵 및 과자류 분류에 속하는 감자빵_못난이 감자크럼볼 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 211kcal의 에너지를 냅니다.\n주요 성분: 단백질 1.33g, 탄수화물 45.33g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 더벤티\n메뉴 특징: 빵 및 과자류 분류에 속하는 감자빵_포슬쫀득 감자빵 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 284kcal의 에너지를 냅니다.\n주요 성분: 단백질 3.64g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 못난이꽈배기\n메뉴 특징: 빵 및 과자류 분류에 속하는 감자빵_못난이감자크럼볼 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 247kcal의 에너지를 냅니다.\n주요 성분: 단백질 1.33g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 바나프레소\n메뉴 특징: 빵 및 과자류 분류에 속하는 감자빵_진짜감자빵 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 242kcal의 에너지를 냅니다.\n주요 성분: 단백질 2.5g, 탄수화물 38.08g, 지방 8.58g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 카페게이트\n메뉴 특징: 빵 및 과자류 분류에 속하는 감자빵_쫀득 감자빵 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 246kcal의 에너지를 냅니다.\n주요 성분: 단백질 5.0g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 할리스\n메뉴 특징: 빵 및 과자류 분류에 속하는 감자빵_찐찐 감자빵 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 247kcal의 에너지를 냅니다.\n주요 성분: 단백질 2.22g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 더벤티\n메뉴 특징: 빵 및 과자류 분류에 속하는 감자빵_포슬쫀득감자빵 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 284kcal의 에너지를 냅니다.\n주요 성분: 단백질 3.64g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 뚜레쥬르\n메뉴 특징: 빵 및 과자류 분류에 속하는 건포도빵_건포도빵 (대) 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 311kcal의 에너지를 냅니다.\n주요 성분: 단백질 7.53g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 뚜레쥬르\n메뉴 특징: 빵 및 과자류 분류에 속하는 건포도빵_건포도빵 (소) 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 310kcal의 에너지를 냅니다.\n주요 성분: 단백질 7.76g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
#   '브랜드: 따삐오\n메뉴 특징: 빵 및 과자류 분류에 속하는 건포도빵_우리쌀건포도브레드 메뉴입니다.\n영양 및 열량: 1회 제공량 100g 기준으로 265kcal의 에너지를 냅니다.\n주요 성분: 단백질 6.0g, 탄수화물 0.0g, 지방 0.0g이 포함되어 균형 잡힌 식사가 가능합니다.',
# ...
#   {'company_name': '버거킹',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.8,
#    'food_name': '버거_더블비프불고기 버거',
#    'food_id': 'D202-091000000-0164'},
#   {'food_name': '버거_더블오리지널치즈 버거',
#    'protein_inq': 2.04,
#    'company_name': '버거킹',
#    'food_id': 'D202-091000000-0165',
#    'na_k_ratio': 0.0},
#   {'na_k_ratio': 0.0,
#    'protein_inq': 1.65,
#    'food_name': '버거_더블치즈 베이컨 시그니처 버거',
#    'food_id': 'D202-091000000-0166',
#    'company_name': '노브랜드버거'},
#   {'food_name': '버거_더블치즈 버거',
#    'food_id': 'D202-091000000-0167',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.86,
#    'company_name': '프랭크버거'},
#   {'company_name': '프랭크버거',
#    'food_id': 'D202-091000000-0168',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_더블치즈 버거 (L)',
#    'protein_inq': 1.77},
#   {'food_name': '버거_더블 한우불고기 버거',
#    'na_k_ratio': 0.0,
#    'protein_inq': 2.18,
#    'food_id': 'D202-091000000-0169',
#    'company_name': '롯데리아'},
#   {'company_name': '맘스터치',
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0170',
#    'food_name': '버거_디럭스불고기 버거',
#    'protein_inq': 1.42},
#   {'company_name': '맘스터치',
#    'food_name': '버거_딥치즈싸이 버거',
#    'protein_inq': 1.67,
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0172'},
#   {'food_name': '버거_뚱카츠 버거',
#    'protein_inq': 1.45,
#    'company_name': '뉴욕버거',
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0173'},
#   {'food_name': '버거_리아미라클2 버거',
#    'food_id': 'D202-091000000-0174',
#    'protein_inq': 1.55,
#    'na_k_ratio': 0.0,
#    'company_name': '롯데리아'},
#   {'food_name': '버거_리얼 딥치즈 버거',
#    'company_name': '뉴욕버거',
#    'food_id': 'D202-091000000-0175',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.94},
#   {'food_id': 'D202-091000000-0176',
#    'protein_inq': 1.57,
#    'food_name': '버거_마라싸이 버거',
#    'na_k_ratio': 0.0,
#    'company_name': '맘스터치'},
#   {'food_name': '버거_맥스파이시상하이 버거',
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0177',
#    'company_name': '맥도날드',
#    'protein_inq': 1.74},
#   {'company_name': '맥도날드',
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0178',
#    'protein_inq': 1.39,
#    'food_name': '버거_맥크리스피디럭스 버거'},
#   {'protein_inq': 1.42,
#    'food_id': 'D202-091000000-0179',
#    'company_name': '맥도날드',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_맥크리스피클래식 버거'},
#   {'food_name': '버거_머쉬룸 버거',
#    'food_id': 'D202-091000000-0180',
#    'company_name': '프랭크버거',
#    'protein_inq': 1.49,
#    'na_k_ratio': 0.0},
#   {'food_id': 'D202-091000000-0181',
#    'protein_inq': 1.46,
#    'food_name': '버거_머쉬룸 버거 (L)',
#    'na_k_ratio': 0.0,
#    'company_name': '프랭크버거'},
#   {'food_name': '버거_바비큐치킨 버거',
#    'food_id': 'D202-091000000-0182',
#    'na_k_ratio': 0.0,
#    'company_name': '버거킹',
#    'protein_inq': 1.48},
#   {'food_id': 'D202-091000000-0183',
#    'food_name': '버거_BBQ 치킨 버거',
#    'company_name': '비비큐',
#    'protein_inq': 1.69,
#    'na_k_ratio': 0.0},
#   {'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0185',
#    'food_name': '버거_베이컨치즈 버거',
#    'protein_inq': 2.26,
#    'company_name': '프랭크버거'},
#   {'protein_inq': 1.81,
#    'food_id': 'D202-091000000-0186',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_베이컨치즈 버거 (L)',
#    'company_name': '프랭크버거'},
#   {'protein_inq': 1.46,
#    'food_name': '버거_베이컨햄 에그번',
#    'food_id': 'D202-091000000-0187',
#    'na_k_ratio': 0.0,
#    'company_name': '롯데리아'},
#   {'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0188',
#    'company_name': '롯데리아',
#    'food_name': '버거_불고기 베이컨 버거',
#    'protein_inq': 1.53},
#   {'food_id': 'D202-091000000-0189',
#    'protein_inq': 1.62,
#    'na_k_ratio': 0.0,
#    'company_name': '롯데리아',
#    'food_name': '버거_불고기 익스트림 오징어 버거'},
#   {'food_name': '버거_블랙바비큐와퍼 버거',
#    'company_name': '버거킹',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.68,
#    'food_id': 'D202-091000000-0190'},
#   {'food_name': '버거_블랙바비큐콰트로치즈와퍼 버거',
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0191',
#    'protein_inq': 1.72,
#    'company_name': '버거킹'},
#   {'food_id': 'D202-091000000-0192',
#    'company_name': '버거킹',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.52,
#    'food_name': '버거_비프&슈림프 버거'},
#   {'protein_inq': 1.77,
#    'food_name': '버거_비프스테이크 버거',
#    'company_name': '맘스터치',
#    'food_id': 'D202-091000000-0193',
#    'na_k_ratio': 0.0},
#   {'food_id': 'D202-091000000-0194',
#    'na_k_ratio': 0.0,
#    'company_name': '뉴욕버거',
#    'protein_inq': 1.61,
#    'food_name': '버거_빈스미트 핫도그'},
#   {'na_k_ratio': 0.0,
#    'protein_inq': 1.15,
#    'food_id': 'D202-091000000-0195',
#    'company_name': '롯데리아',
#    'food_name': '버거_새우베이컨 버거'},
#   {'food_id': 'D202-091000000-0196',
#    'food_name': '버거_새우익스트림 레몬크림 버거',
#    'company_name': '롯데리아',
#    'protein_inq': 1.16,
#    'na_k_ratio': 0.0},
#   {'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0197',
#    'protein_inq': 1.05,
#    'company_name': '프랭크버거',
#    'food_name': '버거_쉬림프 버거'},
#   {'food_name': '버거_쉬림프싸이플렉스 버거',
#    'protein_inq': 1.23,
#    'na_k_ratio': 0.0,
#    'company_name': '맘스터치',
#    'food_id': 'D202-091000000-0198'},
#   {'company_name': '버거킹',
#    'food_id': 'D202-091000000-0199',
#    'food_name': '버거_슈림프 버거',
#    'protein_inq': 1.16,
#    'na_k_ratio': 0.0},
#   {'food_name': '버거_스콜쳐 버거 플러스',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.19,
#    'company_name': 'KFC',
#    'food_id': 'D202-091000000-0200'},
#   {'protein_inq': 1.44,
#    'food_name': '버거_스파이시치킨 스낵랩',
#    'food_id': 'D202-091000000-0201',
#    'company_name': '맥도날드',
#    'na_k_ratio': 0.0},
#   {'food_id': 'D202-091000000-0202',
#    'na_k_ratio': 0.0,
#    'company_name': '맘스터치',
#    'protein_inq': 1.88,
#    'food_name': '버거_아라비아따치즈 버거'},
#   {'food_id': 'D202-091000000-0204',
#    'protein_inq': 0.83,
#    'food_name': '버거_에그포테이토 버거',
#    'na_k_ratio': 0.0,
#    'company_name': '뉴욕버거'},
#   {'protein_inq': 1.52,
#    'food_id': 'D202-091000000-0205',
#    'na_k_ratio': 0.0,
#    'company_name': '맘스터치',
#    'food_name': '버거_오리지널미트볼 버거'},
#   {'company_name': '버거킹',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_오리지널스 페퍼잭 더블',
#    'food_id': 'D202-091000000-0206',
#    'protein_inq': 1.88},
#   {'food_id': 'D202-091000000-0207',
#    'company_name': '버거킹',
#    'protein_inq': 1.71,
#    'na_k_ratio': 0.0,
#    'food_name': '버거_오리지널스 페퍼잭 싱글'},
#   {'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0209',
#    'company_name': '뉴욕버거',
#    'protein_inq': 1.24,
#    'food_name': '버거_오찡 버거'},
#   {'protein_inq': 2.34,
#    'company_name': 'KFC',
#    'food_id': 'D202-091000000-0210',
#    'food_name': '버거_징거 BLT 버거',
#    'na_k_ratio': 0.0},
#   {'protein_inq': 1.45,
#    'na_k_ratio': 0.0,
#    'food_name': '버거_창녕갈릭비프 버거',
#    'company_name': '맥도날드',
#    'food_id': 'D202-091000000-0211'},
#   {'food_name': '버거_창녕갈릭치킨 버거',
#    'company_name': '맥도날드',
#    'protein_inq': 1.32,
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0212'},
#   {'food_id': 'D202-091000000-0213',
#    'food_name': '버거_청양마요미트볼 버거',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.64,
#    'company_name': '맘스터치'},
#   {'company_name': '프랭크버거',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.59,
#    'food_name': '버거_치즈 버거',
#    'food_id': 'D202-091000000-0214'},
#   {'food_id': 'D202-091000000-0215',
#    'food_name': '버거_치즈 버거 (L)',
#    'protein_inq': 1.51,
#    'na_k_ratio': 0.0,
#    'company_name': '프랭크버거'},
#   {'company_name': '버거킹',
#    'food_id': 'D202-091000000-0217',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_치킨 버거',
#    'protein_inq': 1.22},
#   {'company_name': '버거킹',
#    'food_id': 'D202-091000000-0218',
#    'food_name': '버거_치킨킹버거',
#    'protein_inq': 1.31,
#    'na_k_ratio': 0.0},
#   {'food_id': 'D202-091000000-0219',
#    'protein_inq': 1.24,
#    'company_name': '버거킹',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_치킨킹BLT 버거'},
#   {'food_name': '버거_치플레핫치킨 버거',
#    'food_id': 'D202-091000000-0220',
#    'protein_inq': 1.43,
#    'company_name': '노브랜드버거',
#    'na_k_ratio': 0.0},
#   {'protein_inq': 1.04,
#    'food_id': 'D202-091000000-0221',
#    'company_name': '맘스터치',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_칠리새우 버거'},
#   {'na_k_ratio': 0.0,
#    'food_name': '버거_칠리 치킹 버거',
#    'company_name': '뉴욕버거',
#    'protein_inq': 1.62,
#    'food_id': 'D202-091000000-0222'},
#   {'protein_inq': 1.3,
#    'food_name': '버거_케이준비프 스낵랩',
#    'na_k_ratio': 0.0,
#    'company_name': '맥도날드',
#    'food_id': 'D202-091000000-0223'},
#   {'food_name': '버거_콰트로 맥앤치즈 버거',
#    'company_name': '노브랜드버거',
#    'food_id': 'D202-091000000-0224',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.39},
#   {'food_name': '버거_클래식치즈 버거 버터번',
#    'food_id': 'D202-091000000-0225',
#    'company_name': '롯데리아',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.18},
#   {'protein_inq': 1.78,
#    'company_name': '맘스터치',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_탄두리싸이 버거',
#    'food_id': 'D202-091000000-0227'},
#   {'na_k_ratio': 0.0,
#    'company_name': '버거킹',
#    'protein_inq': 1.27,
#    'food_id': 'D202-091000000-0229',
#    'food_name': '버거_통새우슈림프 버거'},
#   {'food_name': '버거_투머치 베이컨 버거',
#    'na_k_ratio': 0.0,
#    'protein_inq': 2.02,
#    'food_id': 'D202-091000000-0230',
#    'company_name': '노브랜드버거'},
#   {'food_name': '버거_트리플딥치즈비프 버거',
#    'company_name': '맘스터치',
#    'protein_inq': 1.96,
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0231'},
#   {'protein_inq': 1.71,
#    'food_name': '버거_트리플딥치즈싸이 버거',
#    'food_id': 'D202-091000000-0232',
#    'na_k_ratio': 0.0,
#    'company_name': '맘스터치'},
#   {'food_name': '버거_트리플치즈 버거',
#    'protein_inq': 2.11,
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0233',
#    'company_name': '맥도날드'},
#   {'protein_inq': 2.05,
#    'food_id': 'D202-091000000-0234',
#    'company_name': '롯데리아',
#    'food_name': '버거_티렉스버거 T-REX 버거',
#    'na_k_ratio': 0.0},
#   {'food_id': 'D202-091000000-0235',
#    'company_name': '뉴욕버거',
#    'food_name': '버거_페퍼로니 버거',
#    'protein_inq': 1.58,
#    'na_k_ratio': 0.0},
#   {'company_name': '노브랜드버거',
#    'food_name': '버거_페퍼로니피자 치킨 버거',
#    'food_id': 'D202-091000000-0236',
#    'protein_inq': 1.84,
#    'na_k_ratio': 0.0},
#   {'na_k_ratio': 0.0,
#    'food_name': '버거_프랭크 버거',
#    'protein_inq': 1.6,
#    'food_id': 'D202-091000000-0237',
#    'company_name': '프랭크버거'},
#   {'na_k_ratio': 0.0,
#    'food_name': '버거_프랭크 버거 (L)',
#    'protein_inq': 1.61,
#    'company_name': '프랭크버거',
#    'food_id': 'D202-091000000-0238'},
#   {'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0239',
#    'protein_inq': 1.56,
#    'company_name': '롯데리아',
#    'food_name': '버거_한우트러플머쉬룸 버거'},
#   {'na_k_ratio': 0.0,
#    'company_name': '맥도날드',
#    'protein_inq': 1.78,
#    'food_name': '버거_햄버거',
#    'food_id': 'D202-091000000-0240'},
#   {'na_k_ratio': 0.0,
#    'food_name': '버거_화이트갈릭싸이 버거',
#    'protein_inq': 1.77,
#    'company_name': '맘스터치',
#    'food_id': 'D202-091000000-0241'},
#   {'protein_inq': 1.1,
#    'food_name': '버거_BLT오믈렛킹모닝',
#    'company_name': '버거킹',
#    'food_id': 'D202-091000000-0242',
#    'na_k_ratio': 0.0},
#   {'company_name': '노브랜드버거',
#    'food_id': 'D202-091000000-0243',
#    'food_name': '버거_NBB 어메이징 감바스',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.32},
#   {'na_k_ratio': 0.0,
#    'protein_inq': 1.54,
#    'food_name': '버거_NBB 어메이징 감바스 새우',
#    'food_id': 'D202-091000000-0244',
#    'company_name': '노브랜드버거'},
#   {'food_name': '버거_갈릭치킹버거',
#    'protein_inq': 1.51,
#    'company_name': '뉴욕버거',
#    'food_id': 'D202-091000000-0245',
#    'na_k_ratio': 0.0},
#   {'company_name': 'KFC',
#    'protein_inq': 2.12,
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0246',
#    'food_name': '버거_갓양념징거'},
#   {'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0247',
#    'company_name': '롯데리아',
#    'food_name': '버거_더블 미라클버거',
#    'protein_inq': 1.72},
#   {'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0248',
#    'food_name': '버거_더블 치킨버거',
#    'protein_inq': 1.84,
#    'company_name': '롯데리아'},
#   {'protein_inq': 1.26,
#    'food_id': 'D202-091000000-0249',
#    'company_name': '롯데리아',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_더블 클래식치즈버거'},
#   {'company_name': 'KFC',
#    'protein_inq': 1.66,
#    'food_name': '버거_더블치즈타워',
#    'food_id': 'D202-091000000-0250',
#    'na_k_ratio': 0.0},
#   {'company_name': '맘스터치',
#    'food_name': '버거_딥치즈버거',
#    'protein_inq': 2.22,
#    'food_id': 'D202-091000000-0251',
#    'na_k_ratio': 0.0},
#   {'food_id': 'D202-091000000-0252',
#    'food_name': '버거_딥치즈싸이버거',
#    'protein_inq': 1.64,
#    'na_k_ratio': 0.0,
#    'company_name': '맘스터치'},
#   {'protein_inq': 1.14,
#    'company_name': '롯데리아',
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0253',
#    'food_name': '버거_리아 사각새우 더블'},
#   {'food_id': 'D202-091000000-0254',
#    'company_name': '롯데리아',
#    'protein_inq': 1.08,
#    'food_name': '버거_리아 새우',
#    'na_k_ratio': 0.0},
#   {'na_k_ratio': 0.0,
#    'food_name': '버거_리아 새우 베이컨',
#    'company_name': '롯데리아',
#    'food_id': 'D202-091000000-0255',
#    'protein_inq': 1.14},
#   {'company_name': '롯데리아',
#    'food_name': '버거_미라클버거',
#    'food_id': 'D202-091000000-0256',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.59},
#   {'na_k_ratio': 0.0,
#    'company_name': '롯데리아',
#    'food_id': 'D202-091000000-0257',
#    'food_name': '버거_베이컨에그번',
#    'protein_inq': 1.28},
#   {'na_k_ratio': 0.0,
#    'company_name': '맘스터치',
#    'food_id': 'D202-091000000-0258',
#    'protein_inq': 1.82,
#    'food_name': '버거_불불불불싸이버거'},
#   {'food_name': '버거_불싸이버거',
#    'protein_inq': 1.88,
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0259',
#    'company_name': '맘스터치'},
#   {'protein_inq': 1.29,
#    'company_name': '노브랜드버거',
#    'food_id': 'D202-091000000-0260',
#    'food_name': '버거_비스크 치즈 새우',
#    'na_k_ratio': 0.0},
#   {'food_name': '버거_쉬림프버거',
#    'food_id': 'D202-091000000-0261',
#    'company_name': '버거리',
#    'protein_inq': 0.91,
#    'na_k_ratio': 0.0},
#   {'food_name': '버거_쉬림프싸이플렉스버거',
#    'food_id': 'D202-091000000-0262',
#    'company_name': '맘스터치',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.21},
#   {'protein_inq': 0.99,
#    'company_name': '버거킹',
#    'food_name': '버거_슈림프버거',
#    'food_id': 'D202-091000000-0263',
#    'na_k_ratio': 0.0},
#   {'na_k_ratio': 0.0,
#    'protein_inq': 1.74,
#    'food_id': 'D202-091000000-0264',
#    'food_name': '버거_스리라차치킹버거',
#    'company_name': '뉴욕버거'},
#   {'protein_inq': 1.7,
#    'food_name': '버거_싸이버거',
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0265',
#    'company_name': '맘스터치'},
#   {'protein_inq': 1.61,
#    'na_k_ratio': 0.0,
#    'company_name': '맘스터치',
#    'food_name': '버거_싸이플렉스버거',
#    'food_id': 'D202-091000000-0266'},
#   {'company_name': '맘스터치',
#    'food_id': 'D202-091000000-0267',
#    'protein_inq': 1.89,
#    'na_k_ratio': 0.0,
#    'food_name': '버거_아라비아따치즈버거'},
#   {'company_name': '맘스터치',
#    'food_name': '버거_언빌리버블버거',
#    'protein_inq': 2.07,
#    'food_id': 'D202-091000000-0268',
#    'na_k_ratio': 0.0},
#   {'na_k_ratio': 0.0,
#    'protein_inq': 1.84,
#    'company_name': 'KFC',
#    'food_name': '버거_업그레이비타워',
#    'food_id': 'D202-091000000-0269'},
#   {'protein_inq': 1.11,
#    'food_name': '버거_에그샐러드번',
#    'company_name': '롯데리아',
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0270'},
#   {'protein_inq': 0.83,
#    'food_id': 'D202-091000000-0271',
#    'food_name': '버거_에그포테이토버거',
#    'company_name': '뉴욕버거',
#    'na_k_ratio': 0.0},
#   {'food_id': 'D202-091000000-0272',
#    'company_name': '맘스터치',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_에드워드리 싸이버거',
#    'protein_inq': 2.16},
#   {'food_id': 'D202-091000000-0273',
#    'food_name': '버거_오리지널 새우',
#    'na_k_ratio': 0.0,
#    'company_name': '노브랜드버거',
#    'protein_inq': 1.1},
#   {'food_id': 'D202-091000000-0274',
#    'food_name': '버거_오믈렛킹모닝',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.1,
#    'company_name': '버거킹'},
#   {'food_id': 'D202-091000000-0275',
#    'na_k_ratio': 0.0,
#    'food_name': '버거_오징어 얼라이브버거 매운맛',
#    'company_name': '롯데리아',
#    'protein_inq': 1.32},
#   {'food_id': 'D202-091000000-0276',
#    'company_name': '롯데리아',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.28,
#    'food_name': '버거_오징어 얼라이브버거 블랙페퍼맛'},
#   {'protein_inq': 1.25,
#    'food_id': 'D202-091000000-0277',
#    'company_name': '뉴욕버거',
#    'food_name': '버거_오찡버거',
#    'na_k_ratio': 0.0},
#   {'company_name': '맘스터치',
#    'food_name': '버거_와우스모크디럭스버거',
#    'na_k_ratio': 0.0,
#    'protein_inq': 2.12,
#    'food_id': 'D202-091000000-0278'},
#   {'na_k_ratio': 0.0,
#    'company_name': '뉴욕버거',
#    'food_name': '버거_웰빙머쉬룸버거',
#    'protein_inq': 0.77,
#    'food_id': 'D202-091000000-0279'},
#   {'food_name': '버거_인크레더블버거',
#    'na_k_ratio': 0.0,
#    'protein_inq': 1.87,
#    'food_id': 'D202-091000000-0280',
#    'company_name': '맘스터치'},
#   {'food_name': '버거_징거BLT버거',
#    'protein_inq': 1.93,
#    'na_k_ratio': 0.0,
#    'food_id': 'D202-091000000-0281',
#    'company_name': 'KFC'},
#   {'na_k_ratio': 0.0,
#    'protein_inq': 1.84,
#    'food_name': '버거_징거더블다운통다리',
#    'company_name': 'KFC',
#    'food_id': 'D202-091000000-0282'},
#   ...]}

# %%
# ---------------------------------------------------------
# 4. 범용 유사도 검색 테스트 (Qualitative Verification)
# ---------------------------------------------------------
print("="*50)
print(" [정성적 검증] 유사도 검색(Similarity Search) 테스트")
print("="*50)

test_query = "투썸플레이스 메뉴 중 커피음료 추천해줘"
print(f"Q: '{test_query}'\n")

# k=3 개 추출하여 점수 확인
results = db.similarity_search_with_score(test_query, k=3)

for i, (doc, distance) in enumerate(results, 1):
    # 코사인 거리(Cosine Distance)를 코사인 유사도(Cosine Similarity)로 변환
    similarity = 1 - distance
    
    print(f"[{i}순위] 메뉴: {doc.metadata['company_name']} - {doc.metadata['food_name']}")
    print(f"  - 유사도 점수: {similarity:.4f} " + ("(적합👍)" if similarity >= 0.7 else "(다소 낮음)"))
    print("-" * 40)
# Out:
# ==================================================
#  [정성적 검증] 유사도 검색(Similarity Search) 테스트
# ==================================================
# Q: '투썸플레이스 메뉴 중 커피음료 추천해줘'
#
# [1순위] 메뉴: 투썸플레이스 - 커피_카페모카 아이스(ICED) (R)
#   - 유사도 점수: 0.5858 (다소 낮음)
# ----------------------------------------
# [2순위] 메뉴: 투썸플레이스 - 커피_롱블랫 아이스(ICED) (Short)
#   - 유사도 점수: 0.5771 (다소 낮음)
# ----------------------------------------
# [3순위] 메뉴: 투썸플레이스 - 커피_카페모카 아이스(ICED) (L)
#   - 유사도 점수: 0.5769 (다소 낮음)
# ----------------------------------------

# %%
print("="*50)
print(" [정성적 검증] 유사도 검색(Similarity Search) 테스트")
print("="*50)

test_query = "투썸플레이스 메뉴 중 차가운 음료 추천해줘"

chroma_filter = {
    "company_name": {"$eq": "투썸플레이스"}
}
print(f"Q: '{test_query}'\n")

# k=3 개 추출하여 점수 확인
results = db.similarity_search_with_score(test_query, k=3, filter=chroma_filter)

for i, (doc, distance) in enumerate(results, 1):
    # 코사인 거리(Cosine Distance)를 코사인 유사도(Cosine Similarity)로 변환
    similarity = 1 - distance
    
    print(f"[{i}순위] 메뉴: {doc.metadata['company_name']} - {doc.metadata['food_name']}")
    print(f"  - 유사도 점수: {similarity:.4f} " + ("(적합👍)" if similarity >= 0.7 else "(다소 낮음)"))
    print("-" * 40)
# Out:
# ==================================================
#  [정성적 검증] 유사도 검색(Similarity Search) 테스트
# ==================================================
# Q: '투썸플레이스 메뉴 중 차가운 음료 추천해줘'
#
# [1순위] 메뉴: 투썸플레이스 - 허브차_민트 아이스(ICED) (L)
#   - 유사도 점수: 0.5921 (다소 낮음)
# ----------------------------------------
# [2순위] 메뉴: 투썸플레이스 - 홍차_얼그레이 아이스(ICED) (L)
#   - 유사도 점수: 0.5856 (다소 낮음)
# ----------------------------------------
# [3순위] 메뉴: 투썸플레이스 - 허브차_민트 핫(HOT) (L)
#   - 유사도 점수: 0.5840 (다소 낮음)
# ----------------------------------------

# %%
# ---------------------------------------------------------
# 4. 범용 유사도 검색 테스트 (Qualitative Verification)
# ---------------------------------------------------------
print("="*50)
print(" [정성적 검증] 유사도 검색(Similarity Search) 테스트")
print("="*50)

test_query = "투썸플레이스 메뉴 중 차가운 음료중 칼로리가 10kcal 이하인 것 추천해줘"

chroma_filter = {
    "company_name": {"$eq": "투썸플레이스"}
}
print(f"Q: '{test_query}'\n")

# k=3 개 추출하여 점수 확인
results = db.similarity_search_with_score(test_query, k=3, filter=chroma_filter)

for i, (doc, distance) in enumerate(results, 1):
    # 코사인 거리(Cosine Distance)를 코사인 유사도(Cosine Similarity)로 변환
    similarity = 1 - distance
    
    print(f"[{i}순위] 메뉴: {doc.metadata['company_name']} - {doc.metadata['food_name']}")
    print(f"  - 유사도 점수: {similarity:.4f} " + ("(적합👍)" if similarity >= 0.7 else "(다소 낮음)"))
    print("-" * 40)
# Out:
# ==================================================
#  [정성적 검증] 유사도 검색(Similarity Search) 테스트
# ==================================================
# Q: '투썸플레이스 메뉴 중 차가운 음료중 칼로리가 10kcal 이하인 것 추천해줘'
#
# [1순위] 메뉴: 투썸플레이스 - 스무디_민트초코 프라페 (L)
#   - 유사도 점수: 0.6478 (다소 낮음)
# ----------------------------------------
# [2순위] 메뉴: 투썸플레이스 - 커피_카푸치노 핫(HOT) (R)
#   - 유사도 점수: 0.6476 (다소 낮음)
# ----------------------------------------
# [3순위] 메뉴: 투썸플레이스 - 스무디_민트초코 프라페 (Max)
#   - 유사도 점수: 0.6472 (다소 낮음)
# ----------------------------------------

# %%
import os
import pandas as pd
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain_classic.chains.query_constructor.base import AttributeInfo
from langchain_classic.retrievers.self_query.base import SelfQueryRetriever
from langchain_community.query_constructors.chroma import ChromaTranslator

# ---------------------------------------------------------
# 4. Self-Querying Retriever 구축 및 통합 테스트
# ---------------------------------------------------------
print("\n[Self-Querying Retriever 기반 지능형 검색 테스트]")

# 1. [메타데이터 속성 정의] LLM이 메타데이터를 어떻게 필터링할지 알 수 있도록 친절한 설명서(Schema) 작성
metadata_field_info = [
    AttributeInfo(
        name="company_name",
        description="음식점의 브랜드명 또는 업체명 (예: 투썸플레이스, 교촌치킨 등)",
        type="string",
    ),
    AttributeInfo(
        name="food_name",
        description="메뉴의 고유 이름",
        type="string",
    ),
    AttributeInfo(
        name="protein_inq",
        description="단백질 영양 품질 지표. 수치가 1.0 이상이면 고단백 및 영양이 우수함을 의미함.",
        type="float",
    ),
    AttributeInfo(
        name="na_k_ratio",
        description="나트륨-칼륨 비율. 수치가 낮을수록 건강한 식단임을 의미함.",
        type="float",
    ),
]

# 수정된 부분 1: 문서의 성격을 LLM에게 알려주는 설명으로 변경
document_content_description = "국내 음식점 및 카페 메뉴의 영양 성분, 칼로리, 그리고 메뉴에 대한 세부 설명 정보"

# 2. 쿼리 분석용 LLM 초기화 (비용과 속도가 효율적인 gpt-4o-mini 추천)
llm = ChatOpenAI(temperature=0, model="gpt-4o-mini")

# 3. [리트리버 생성] LLM, Vector DB, 메타데이터 스키마를 결합
retriever = SelfQueryRetriever.from_llm(
    llm,
    db,
    document_content_description,
    metadata_field_info,
    structured_query_translator=ChromaTranslator(), 
    enable_limit=True 
)

# 4. [자연어 필터링 통합 테스트] 
test_query = "투썸플레이스 메뉴 중 커피음료 추천해줘"
print(f"Q: '{test_query}'\n")

# 리트리버 실행 (similarity_search_with_score 대신 invoke 사용)
results = retriever.invoke(test_query)

# 결과 출력
for i, doc in enumerate(results, 1):
    print(f"[{i}순위] 메뉴: {doc.metadata['company_name']} - {doc.metadata['food_name']}")
    print("-" * 40)

# similarity_search_with_score 결과
# [1순위] 메뉴: 투썸플레이스 - 커피_카페모카 아이스(ICED) (R)
#   - 유사도 점수: 0.5858 (다소 낮음)
# ----------------------------------------
# [2순위] 메뉴: 투썸플레이스 - 커피_롱블랫 아이스(ICED) (Short)
#   - 유사도 점수: 0.5771 (다소 낮음)
# ----------------------------------------
# [3순위] 메뉴: 투썸플레이스 - 커피_카페모카 아이스(ICED) (L)
#   - 유사도 점수: 0.5769 (다소 낮음)
# ----------------------------------------
# Out:
# [Self-Querying Retriever 기반 지능형 검색 테스트]
# Q: '투썸플레이스 메뉴 중 커피음료 추천해줘'
#
# [1순위] 메뉴: 투썸플레이스 - 커피_카페모카 아이스(ICED) (L)
# ----------------------------------------
# [2순위] 메뉴: 투썸플레이스 - 커피_카페모카 아이스(ICED) (R)
# ----------------------------------------
# [3순위] 메뉴: 투썸플레이스 - 커피_아메리키토 아이스(ICED) (Max)
# ----------------------------------------
# [4순위] 메뉴: 투썸플레이스 - 커피_롱블랫 아이스(ICED) (Short)
# ----------------------------------------
